# %%
import pickle
import mlflow
import mlflow.sklearn
import pandas as pd
import xgboost as xgb
import seaborn as sns
import matplotlib.pyplot as plt
from hyperopt.pyll import scope
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.svm import LinearSVR
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error, root_mean_squared_error
from sklearn.feature_extraction import DictVectorizer
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor

# %%
# create SQLite mflow.db
mlflow.set_tracking_uri("sqlite:///mlflow.db")
# this will create experiment based on provide name
# also create mlruns folder
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='/home/ubuntu/mlops-datatalk/02_experiment_tracking/mlruns/1', creation_time=1715068447646, experiment_id='1', last_update_time=1715068447646, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
# delete experiment based on its id
# mlflow.delete_experiment(experiment_id = '1')

# %%
# basic function
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('../data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('../data/green_tripdata_2021-02.parquet')

print(len(df_train), len(df_val))
# Out:
# 73908 61921

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

categorical = ['PU_DO']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient = 'records')
x_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient = 'records')
x_val = dv.transform(val_dicts)

target = 'duration'

y_train = df_train[target].values
y_val = df_val[target].values

# %% [markdown]
# #### Workflow without MLOps

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)

y_pred = lr.predict(x_val)

root_mean_squared_error(y_val, y_pred)

with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %% [markdown]
# #### Workflow with MLOps

# %%
with mlflow.start_run():
    # log detail
    mlflow.set_tag("developer", "christopher")

    # log parameter
    mlflow.log_param("train-data-path", "../data/green_tripdata_2021-01.csv")
    mlflow.log_param("valid-data-path", "../data/green_tripdata_2021-02.csv")

    alpha = 0.1

    # log parameter
    mlflow.log_param("alpha", alpha)

    lr = Lasso(alpha)
    lr.fit(x_train, y_train)

    y_pred = lr.predict(x_val)

    rmse = root_mean_squared_error(y_val, y_pred)

    # log rmse metric
    mlflow.log_metric("rmse", rmse)

    # save model locally
    with open('models/lin_reg.bin', 'wb') as f_out:
        pickle.dump((dv, lr), f_out)

    # log artifact for model
    mlflow.log_artifact(local_path = "models/lin_reg.bin", artifact_path = "models_pickle")

# %% [markdown]
# #### MLOps with XGBoost training

# %%
train = xgb.DMatrix(x_train, label = y_train)
valid = xgb.DMatrix(x_val, label = y_val)

# %%
def objective(params):
    with mlflow.start_run():
        # log detail
        mlflow.set_tag("developer", "christopher")
        # log detail
        mlflow.set_tag("model", "xgboost")
        # log parameter
        mlflow.log_params(params)

        booster = xgb.train(
            params = params,
            dtrain = train,
            num_boost_round = 1000,
            evals = [(valid, 'validation')],
            early_stopping_rounds = 50
        )

        y_pred = booster.predict(valid)
        rmse = root_mean_squared_error(y_val, y_pred)

        # log metric
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
# search space to find the best hyperparameter
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:squarederror',
    'seed': 42
}

best_result = fmin(
    fn = objective,
    space = search_space,
    algo = tpe.suggest,
    max_evals = 50,
    trials = Trials()
)

print(best_result)
# Out:
# [0]	validation-rmse:11.41578
# [1]	validation-rmse:10.72489
# [2]	validation-rmse:10.12867
# [3]	validation-rmse:9.61566
# [4]	validation-rmse:9.17692
# [5]	validation-rmse:8.80164
# [6]	validation-rmse:8.48287
# [7]	validation-rmse:8.21328
# [8]	validation-rmse:7.98621
# [9]	validation-rmse:7.79534
# [10]	validation-rmse:7.63368
# [11]	validation-rmse:7.49811
# [12]	validation-rmse:7.38492
# [13]	validation-rmse:7.28947
# [14]	validation-rmse:7.20963
# [15]	validation-rmse:7.14121
# [16]	validation-rmse:7.08442
# [17]	validation-rmse:7.03639
# [18]	validation-rmse:6.99543
# [19]	validation-rmse:6.96004
# [20]	validation-rmse:6.93087
# [21]	validation-rmse:6.90706
# [22]	validation-rmse:6.88558
# [23]	validation-rmse:6.86736
# [24]	validation-rmse:6.85133
# [25]	validation-rmse:6.83700
# [26]	validation-rmse:6.82463
# [27]	validation-rmse:6.81481
# [28]	validation-rmse:6.80594
# [29]	validation-rmse:6.79783
# [30]	validation-rmse:6.79036
# [31]	validation-rmse:6.78366
# [32]	validation-rmse:6.77810
# [33]	validation-rmse:6.77385
# [34]	validation-rmse:6.76887
# [35]	validation-rmse:6.76497
# [36]	validation-rmse:6.76164
# [37]	validation-rmse:6.75818
# [38]	validation-rmse:6.75537
# [39]	validation-rmse:6.75254
# [40]	validation-rmse:6.74981
# [41]	validation-rmse:6.74817
# [42]	validation-rmse:6.74601
# [43]	validation-rmse:6.74480
# [44]	validation-rmse:6.74418
# [45]	validation-rmse:6.74315
# [46]	validation-rmse:6.74212
# [47]	validation-rmse:6.74028
# [48]	validation-rmse:6.73831
# [49]	validation-rmse:6.73744
# [50]	validation-rmse:6.73694
# [51]	validation-rmse:6.73611
# [52]	validation-rmse:6.73566
# [53]	validation-rmse:6.73465
# [54]	validation-rmse:6.73419
# [55]	validation-rmse:6.73362
# [56]	validation-rmse:6.73265
# [57]	validation-rmse:6.73196
# [58]	validation-rmse:6.73101
# [59]	validation-rmse:6.72993
# [60]	validation-rmse:6.72915
# [61]	validation-rmse:6.72849
# [62]	validation-rmse:6.72751
# [63]	validation-rmse:6.72669
# [64]	validation-rmse:6.72546
# [65]	validation-rmse:6.72498
# [66]	validation-rmse:6.72434
# [67]	validation-rmse:6.72376
# [68]	validation-rmse:6.72245
# [69]	validation-rmse:6.72176
# [70]	validation-rmse:6.72116
# [71]	validation-rmse:6.72074
# [72]	validation-rmse:6.71996
# [73]	validation-rmse:6.71952
# [74]	validation-rmse:6.71872
# [75]	validation-rmse:6.71808
# [76]	validation-rmse:6.71768
# [77]	validation-rmse:6.71701
# [78]	validation-rmse:6.71631
# [79]	validation-rmse:6.71572
# [80]	validation-rmse:6.71509
# [81]	validation-rmse:6.71433
# [82]	validation-rmse:6.71367
# [83]	validation-rmse:6.71325
# [84]	validation-rmse:6.71269
# [85]	validation-rmse:6.71238
# [86]	validation-rmse:6.71183
# [87]	validation-rmse:6.71134
# [88]	validation-rmse:6.71087
# [89]	validation-rmse:6.70959
# [90]	validation-rmse:6.70920
# [91]	validation-rmse:6.70879
# [92]	validation-rmse:6.70841
# [93]	validation-rmse:6.70798
# [94]	validation-rmse:6.70735
# [95]	validation-rmse:6.70698
# [96]	validation-rmse:6.70653
# [97]	validation-rmse:6.70607
# [98]	validation-rmse:6.70562
# [99]	validation-rmse:6.70520
# [100]	validation-rmse:6.70470
# [101]	validation-rmse:6.70437
# [102]	validation-rmse:6.70404
# [103]	validation-rmse:6.70327
# [104]	validation-rmse:6.70283
# [105]	validation-rmse:6.70142
# [106]	validation-rmse:6.70090
# [107]	validation-rmse:6.70059
# [108]	validation-rmse:6.70016
# [109]	validation-rmse:6.69974
# [110]	validation-rmse:6.69949
# [111]	validation-rmse:6.69899
# [112]	validation-rmse:6.69862
# [113]	validation-rmse:6.69827
# [114]	validation-rmse:6.69780
# [115]	validation-rmse:6.69739
# [116]	validation-rmse:6.69706
# [117]	validation-rmse:6.69632
# [118]	validation-rmse:6.69585
# [119]	validation-rmse:6.69551
# [120]	validation-rmse:6.69501
# [121]	validation-rmse:6.69471
# [122]	validation-rmse:6.69430
# [123]	validation-rmse:6.69352
# [124]	validation-rmse:6.69315
# [125]	validation-rmse:6.69289
# [126]	validation-rmse:6.69256
# [127]	validation-rmse:6.69220
# [128]	validation-rmse:6.69165
# [129]	validation-rmse:6.69132
# [130]	validation-rmse:6.69045
# [131]	validation-rmse:6.69005
# [132]	validation-rmse:6.68971
# [133]	validation-rmse:6.68945
# [134]	validation-rmse:6.68911
# [135]	validation-rmse:6.68860
# [136]	validation-rmse:6.68824
# [137]	validation-rmse:6.68779
# [138]	validation-rmse:6.68735
# [139]	validation-rmse:6.68710
# [140]	validation-rmse:6.68673
# [141]	validation-rmse:6.68635
# [142]	validation-rmse:6.68606
# [143]	validation-rmse:6.68582
# [144]	validation-rmse:6.68562
# [145]	validation-rmse:6.68529
# [146]	validation-rmse:6.68492
# [147]	validation-rmse:6.68452
# [148]	validation-rmse:6.68425
# [149]	validation-rmse:6.68404
# [150]	validation-rmse:6.68353
# [151]	validation-rmse:6.68316
# [152]	validation-rmse:6.68288
# [153]	validation-rmse:6.68259
# [154]	validation-rmse:6.68222
# [155]	validation-rmse:6.68181
# [156]	validation-rmse:6.68139
# [157]	validation-rmse:6.68109
# [158]	validation-rmse:6.68094
# [159]	validation-rmse:6.68057
# [160]	validation-rmse:6.68001
# [161]	validation-rmse:6.67947
# [162]	validation-rmse:6.67919
# [163]	validation-rmse:6.67871
# [164]	validation-rmse:6.67851
# [165]	validation-rmse:6.67804
# [166]	validation-rmse:6.67773
# [167]	validation-rmse:6.67750
# [168]	validation-rmse:6.67708
# [169]	validation-rmse:6.67687
# [170]	validation-rmse:6.67661
# [171]	validation-rmse:6.67637
# [172]	validation-rmse:6.67607
# [173]	validation-rmse:6.67578
# [174]	validation-rmse:6.67564
# [175]	validation-rmse:6.67533
# [176]	validation-rmse:6.67487
# [177]	validation-rmse:6.67436
# [178]	validation-rmse:6.67390
# [179]	validation-rmse:6.67363
# [180]	validation-rmse:6.67349
# [181]	validation-rmse:6.67308
# [182]	validation-rmse:6.67281
# [183]	validation-rmse:6.67243
# [184]	validation-rmse:6.67173
# [185]	validation-rmse:6.67159
# [186]	validation-rmse:6.67129
# [187]	validation-rmse:6.67107
# [188]	validation-rmse:6.67083
# [189]	validation-rmse:6.67055
# [190]	validation-rmse:6.67038
# [191]	validation-rmse:6.66995
# [192]	validation-rmse:6.66948
# [193]	validation-rmse:6.66925
# [194]	validation-rmse:6.66883
# [195]	validation-rmse:6.66861
# [196]	validation-rmse:6.66815
# [197]	validation-rmse:6.66785
# [198]	validation-rmse:6.66756
# [199]	validation-rmse:6.66729
# [200]	validation-rmse:6.66700
# [201]	validation-rmse:6.66667
# [202]	validation-rmse:6.66639
# [203]	validation-rmse:6.66626
# [204]	validation-rmse:6.66605
# [205]	validation-rmse:6.66577
# [206]	validation-rmse:6.66556
# [207]	validation-rmse:6.66530
# [208]	validation-rmse:6.66479
# [209]	validation-rmse:6.66441
# [210]	validation-rmse:6.66402
# [211]	validation-rmse:6.66369
# [212]	validation-rmse:6.66357
# [213]	validation-rmse:6.66319
# [214]	validation-rmse:6.66294
# [215]	validation-rmse:6.66262
# [216]	validation-rmse:6.66236
# [217]	validation-rmse:6.66202
# [218]	validation-rmse:6.66185
# [219]	validation-rmse:6.66059
# [220]	validation-rmse:6.66045
# [221]	validation-rmse:6.66031
# [222]	validation-rmse:6.66009
# [223]	validation-rmse:6.65994
# [224]	validation-rmse:6.65971
# [225]	validation-rmse:6.65949
# [226]	validation-rmse:6.65935
# [227]	validation-rmse:6.65896
# [228]	validation-rmse:6.65874
# [229]	validation-rmse:6.65845
# [230]	validation-rmse:6.65826
# [231]	validation-rmse:6.65801
# [232]	validation-rmse:6.65754
# [233]	validation-rmse:6.65733
# [234]	validation-rmse:6.65715
# [235]	validation-rmse:6.65693
# [236]	validation-rmse:6.65671
# [237]	validation-rmse:6.65649
# [238]	validation-rmse:6.65631
# [239]	validation-rmse:6.65601
# [240]	validation-rmse:6.65593
# [241]	validation-rmse:6.65568
# [242]	validation-rmse:6.65562
# [243]	validation-rmse:6.65478
# [244]	validation-rmse:6.65471
# [245]	validation-rmse:6.65454
# [246]	validation-rmse:6.65412
# [247]	validation-rmse:6.65387
# [248]	validation-rmse:6.65366
# [249]	validation-rmse:6.65354
# [250]	validation-rmse:6.65313
# [251]	validation-rmse:6.65289
# [252]	validation-rmse:6.65265
# [253]	validation-rmse:6.65242
# [254]	validation-rmse:6.65203
# [255]	validation-rmse:6.65178
# [256]	validation-rmse:6.65162
# [257]	validation-rmse:6.65134
# [258]	validation-rmse:6.65114
# [259]	validation-rmse:6.65082
# [260]	validation-rmse:6.65057
# [261]	validation-rmse:6.65034
# [262]	validation-rmse:6.65016
# [263]	validation-rmse:6.65000
# [264]	validation-rmse:6.64994
# [265]	validation-rmse:6.64968
# [266]	validation-rmse:6.64948
# [267]	validation-rmse:6.64934
# [268]	validation-rmse:6.64894
# [269]	validation-rmse:6.64872
# [270]	validation-rmse:6.64852
# [271]	validation-rmse:6.64848
# [272]	validation-rmse:6.64802
# [273]	validation-rmse:6.64781
# [274]	validation-rmse:6.64754
# [275]	validation-rmse:6.64728
# [276]	validation-rmse:6.64713
# [277]	validation-rmse:6.64695
# [278]	validation-rmse:6.64668
# [279]	validation-rmse:6.64649
# [280]	validation-rmse:6.64628
# [281]	validation-rmse:6.64613
# [282]	validation-rmse:6.64602
# [283]	validation-rmse:6.64584
# [284]	validation-rmse:6.64570
# [285]	validation-rmse:6.64540
# [286]	validation-rmse:6.64527
# [287]	validation-rmse:6.64456
# [288]	validation-rmse:6.64443
# [289]	validation-rmse:6.64419
# [290]	validation-rmse:6.64405
# [291]	validation-rmse:6.64340
# [292]	validation-rmse:6.64319
# [293]	validation-rmse:6.64299
# [294]	validation-rmse:6.64291
# [295]	validation-rmse:6.64281
# [296]	validation-rmse:6.64259
# [297]	validation-rmse:6.64240
# [298]	validation-rmse:6.64224
# [299]	validation-rmse:6.64199
# [300]	validation-rmse:6.64187
# [301]	validation-rmse:6.64151
# [302]	validation-rmse:6.64133
# [303]	validation-rmse:6.64122
# [304]	validation-rmse:6.64098
# [305]	validation-rmse:6.64037
# [306]	validation-rmse:6.64021
# [307]	validation-rmse:6.64008
# [308]	validation-rmse:6.63996
# [309]	validation-rmse:6.63965
# [310]	validation-rmse:6.63941
# [311]	validation-rmse:6.63926
# [312]	validation-rmse:6.63909
# [313]	validation-rmse:6.63885
# [314]	validation-rmse:6.63860
# [315]	validation-rmse:6.63846
# [316]	validation-rmse:6.63754
# [317]	validation-rmse:6.63736
# [318]	validation-rmse:6.63724
# [319]	validation-rmse:6.63700
# [320]	validation-rmse:6.63681
# [321]	validation-rmse:6.63667
# [322]	validation-rmse:6.63657
# [323]	validation-rmse:6.63639
# [324]	validation-rmse:6.63623
# [325]	validation-rmse:6.63598
# [326]	validation-rmse:6.63582
# [327]	validation-rmse:6.63557
# [328]	validation-rmse:6.63531
# [329]	validation-rmse:6.63489
# [330]	validation-rmse:6.63482
# [331]	validation-rmse:6.63456
# [332]	validation-rmse:6.63430
# [333]	validation-rmse:6.63416
# [334]	validation-rmse:6.63398
# [335]	validation-rmse:6.63390
# [336]	validation-rmse:6.63381
# [337]	validation-rmse:6.63348
# [338]	validation-rmse:6.63340
# [339]	validation-rmse:6.63313
# [340]	validation-rmse:6.63297
# [341]	validation-rmse:6.63276
# [342]	validation-rmse:6.63246
# [343]	validation-rmse:6.63223
# [344]	validation-rmse:6.63196
# [345]	validation-rmse:6.63183
# [346]	validation-rmse:6.63166
# [347]	validation-rmse:6.63151
# [348]	validation-rmse:6.63140
# [349]	validation-rmse:6.63120
# [350]	validation-rmse:6.63105
# [351]	validation-rmse:6.63089
# [352]	validation-rmse:6.63081
# [353]	validation-rmse:6.63023
# [354]	validation-rmse:6.63013
# [355]	validation-rmse:6.62989
# [356]	validation-rmse:6.62983
# [357]	validation-rmse:6.62969
# [358]	validation-rmse:6.62948
# [359]	validation-rmse:6.62935
# [360]	validation-rmse:6.62927
# [361]	validation-rmse:6.62914
# [362]	validation-rmse:6.62904
# [363]	validation-rmse:6.62881
# [364]	validation-rmse:6.62874
# [365]	validation-rmse:6.62862
# [366]	validation-rmse:6.62847
# [367]	validation-rmse:6.62832
# [368]	validation-rmse:6.62829
# [369]	validation-rmse:6.62829
# [370]	validation-rmse:6.62818
# [371]	validation-rmse:6.62805
# [372]	validation-rmse:6.62782
# [373]	validation-rmse:6.62769
# [374]	validation-rmse:6.62752
# [375]	validation-rmse:6.62732
# [376]	validation-rmse:6.62721
# [377]	validation-rmse:6.62707
# [378]	validation-rmse:6.62674
# [379]	validation-rmse:6.62666
# [380]	validation-rmse:6.62642
# [381]	validation-rmse:6.62622
# [382]	validation-rmse:6.62605
# [383]	validation-rmse:6.62593
# [384]	validation-rmse:6.62584
# [385]	validation-rmse:6.62572
# [386]	validation-rmse:6.62566
# [387]	validation-rmse:6.62539
# [388]	validation-rmse:6.62526
# [389]	validation-rmse:6.62510
# [390]	validation-rmse:6.62494
# [391]	validation-rmse:6.62485
# [392]	validation-rmse:6.62468
# [393]	validation-rmse:6.62455
# [394]	validation-rmse:6.62439
# [395]	validation-rmse:6.62420
# [396]	validation-rmse:6.62416
# [397]	validation-rmse:6.62411
# [398]	validation-rmse:6.62384
# [399]	validation-rmse:6.62369
# [400]	validation-rmse:6.62352
# [401]	validation-rmse:6.62345
# [402]	validation-rmse:6.62332
# [403]	validation-rmse:6.62299
# [404]	validation-rmse:6.62273
# [405]	validation-rmse:6.62264
# [406]	validation-rmse:6.62248
# [407]	validation-rmse:6.62235
# [408]	validation-rmse:6.62233
# [409]	validation-rmse:6.62222
# [410]	validation-rmse:6.62202
# [411]	validation-rmse:6.62188
# [412]	validation-rmse:6.62172
# [413]	validation-rmse:6.62157
# [414]	validation-rmse:6.62139
# [415]	validation-rmse:6.62117
# [416]	validation-rmse:6.62095
# [417]	validation-rmse:6.62093
# [418]	validation-rmse:6.62090
# [419]	validation-rmse:6.62070
# [420]	validation-rmse:6.62059
# [421]	validation-rmse:6.62043
# [422]	validation-rmse:6.62020
# [423]	validation-rmse:6.62008
# [424]	validation-rmse:6.61995
# [425]	validation-rmse:6.61990
# [426]	validation-rmse:6.61972
# [427]	validation-rmse:6.61943
# [428]	validation-rmse:6.61933
# [429]	validation-rmse:6.61928
# [430]	validation-rmse:6.61915
# [431]	validation-rmse:6.61895
# [432]	validation-rmse:6.61890
# [433]	validation-rmse:6.61874
# [434]	validation-rmse:6.61866
# [435]	validation-rmse:6.61860
# [436]	validation-rmse:6.61855
# [437]	validation-rmse:6.61849
# [438]	validation-rmse:6.61838
# [439]	validation-rmse:6.61833
# [440]	validation-rmse:6.61813
# [441]	validation-rmse:6.61799
# [442]	validation-rmse:6.61793
# [443]	validation-rmse:6.61786
# [444]	validation-rmse:6.61776
# [445]	validation-rmse:6.61764
# [446]	validation-rmse:6.61758
# [447]	validation-rmse:6.61751
# [448]	validation-rmse:6.61730
# [449]	validation-rmse:6.61719
# [450]	validation-rmse:6.61710
# [451]	validation-rmse:6.61699
# [452]	validation-rmse:6.61699
# [453]	validation-rmse:6.61690
# [454]	validation-rmse:6.61654
# [455]	validation-rmse:6.61641
# [456]	validation-rmse:6.61630
# [457]	validation-rmse:6.61612
# [458]	validation-rmse:6.61604
# [459]	validation-rmse:6.61588
# [460]	validation-rmse:6.61569
# [461]	validation-rmse:6.61547
# [462]	validation-rmse:6.61528
# [463]	validation-rmse:6.61520
# [464]	validation-rmse:6.61522
# [465]	validation-rmse:6.61515
# [466]	validation-rmse:6.61507
# [467]	validation-rmse:6.61499
# [468]	validation-rmse:6.61486
# [469]	validation-rmse:6.61474
# [470]	validation-rmse:6.61463
# [471]	validation-rmse:6.61409
# [472]	validation-rmse:6.61353
# [473]	validation-rmse:6.61338
# [474]	validation-rmse:6.61317
# [475]	validation-rmse:6.61303
# [476]	validation-rmse:6.61291
# [477]	validation-rmse:6.61289
# [478]	validation-rmse:6.61278
# [479]	validation-rmse:6.61251
# [480]	validation-rmse:6.61242
# [481]	validation-rmse:6.61227
# [482]	validation-rmse:6.61220
# [483]	validation-rmse:6.61201
# [484]	validation-rmse:6.61197
# [485]	validation-rmse:6.61193
# [486]	validation-rmse:6.61154
# [487]	validation-rmse:6.61144
# [488]	validation-rmse:6.61141
# [489]	validation-rmse:6.61133
# [490]	validation-rmse:6.61123
# [491]	validation-rmse:6.61108
# [492]	validation-rmse:6.61100
# [493]	validation-rmse:6.61090
# [494]	validation-rmse:6.61082
# [495]	validation-rmse:6.61067
# [496]	validation-rmse:6.61060
# [497]	validation-rmse:6.61054
# [498]	validation-rmse:6.61039
# [499]	validation-rmse:6.61023
# [500]	validation-rmse:6.61013
# [501]	validation-rmse:6.60987
# [502]	validation-rmse:6.60971
# [503]	validation-rmse:6.60967
# [504]	validation-rmse:6.60955
# [505]	validation-rmse:6.60950
# [506]	validation-rmse:6.60936
# [507]	validation-rmse:6.60927
# [508]	validation-rmse:6.60909
# [509]	validation-rmse:6.60903
# [510]	validation-rmse:6.60895
# [511]	validation-rmse:6.60892
# [512]	validation-rmse:6.60885
# [513]	validation-rmse:6.60883
# [514]	validation-rmse:6.60858
# [515]	validation-rmse:6.60844
# [516]	validation-rmse:6.60825
# [517]	validation-rmse:6.60777
# [518]	validation-rmse:6.60766
# [519]	validation-rmse:6.60765
# [520]	validation-rmse:6.60759
# [521]	validation-rmse:6.60747
# [522]	validation-rmse:6.60742
# [523]	validation-rmse:6.60735
# [524]	validation-rmse:6.60727
# [525]	validation-rmse:6.60712
# [526]	validation-rmse:6.60703
# [527]	validation-rmse:6.60710
# [528]	validation-rmse:6.60706
# [529]	validation-rmse:6.60692
# [530]	validation-rmse:6.60686
# [531]	validation-rmse:6.60670
# [532]	validation-rmse:6.60662
# [533]	validation-rmse:6.60648
# [534]	validation-rmse:6.60641
# [535]	validation-rmse:6.60624
# [536]	validation-rmse:6.60612
# [537]	validation-rmse:6.60612
# [538]	validation-rmse:6.60605
# [539]	validation-rmse:6.60599
# [540]	validation-rmse:6.60566
# [541]	validation-rmse:6.60559
# [542]	validation-rmse:6.60551
# [543]	validation-rmse:6.60528
# [544]	validation-rmse:6.60478
# [545]	validation-rmse:6.60474
# [546]	validation-rmse:6.60468
# [547]	validation-rmse:6.60464
# [548]	validation-rmse:6.60451
# [549]	validation-rmse:6.60443
# [550]	validation-rmse:6.60432
# [551]	validation-rmse:6.60415
# [552]	validation-rmse:6.60403
# [553]	validation-rmse:6.60403
# [554]	validation-rmse:6.60395
# [555]	validation-rmse:6.60381
# [556]	validation-rmse:6.60361
# [557]	validation-rmse:6.60345
# [558]	validation-rmse:6.60335
# [559]	validation-rmse:6.60319
# [560]	validation-rmse:6.60312
# [561]	validation-rmse:6.60299
# [562]	validation-rmse:6.60279
# [563]	validation-rmse:6.60280
# [564]	validation-rmse:6.60275
# [565]	validation-rmse:6.60270
# [566]	validation-rmse:6.60264
# [567]	validation-rmse:6.60262
# [568]	validation-rmse:6.60249
# [569]	validation-rmse:6.60230
# [570]	validation-rmse:6.60218
# [571]	validation-rmse:6.60215
# [572]	validation-rmse:6.60194
# [573]	validation-rmse:6.60173
# [574]	validation-rmse:6.60169
# [575]	validation-rmse:6.60160
# [576]	validation-rmse:6.60149
# [577]	validation-rmse:6.60144
# [578]	validation-rmse:6.60081
# [579]	validation-rmse:6.60066
# [580]	validation-rmse:6.60056
# [581]	validation-rmse:6.60045
# [582]	validation-rmse:6.60033
# [583]	validation-rmse:6.60015
# [584]	validation-rmse:6.60008
# [585]	validation-rmse:6.59998
# [586]	validation-rmse:6.59996
# [587]	validation-rmse:6.59989
# [588]	validation-rmse:6.59982
# [589]	validation-rmse:6.59982
# [590]	validation-rmse:6.59975
# [591]	validation-rmse:6.59967
# [592]	validation-rmse:6.59955
# [593]	validation-rmse:6.59927
# [594]	validation-rmse:6.59922
# [595]	validation-rmse:6.59910
# [596]	validation-rmse:6.59908
# [597]	validation-rmse:6.59902
# [598]	validation-rmse:6.59898
# [599]	validation-rmse:6.59894
# [600]	validation-rmse:6.59884
# [601]	validation-rmse:6.59858
# [602]	validation-rmse:6.59847
# [603]	validation-rmse:6.59836
# [604]	validation-rmse:6.59837
# [605]	validation-rmse:6.59827
# [606]	validation-rmse:6.59827
# [607]	validation-rmse:6.59814
# [608]	validation-rmse:6.59809
# [609]	validation-rmse:6.59802
# [610]	validation-rmse:6.59801
# [611]	validation-rmse:6.59796
# [612]	validation-rmse:6.59784
# [613]	validation-rmse:6.59779
# [614]	validation-rmse:6.59768
# [615]	validation-rmse:6.59752
# [616]	validation-rmse:6.59738
# [617]	validation-rmse:6.59728
# [618]	validation-rmse:6.59724
# [619]	validation-rmse:6.59711
# [620]	validation-rmse:6.59699
# [621]	validation-rmse:6.59698
# [622]	validation-rmse:6.59688
# [623]	validation-rmse:6.59687
# [624]	validation-rmse:6.59686
# [625]	validation-rmse:6.59674
# [626]	validation-rmse:6.59651
# [627]	validation-rmse:6.59644
# [628]	validation-rmse:6.59640
# [629]	validation-rmse:6.59617
# [630]	validation-rmse:6.59598
# [631]	validation-rmse:6.59595
# [632]	validation-rmse:6.59590
# [633]	validation-rmse:6.59582
# [634]	validation-rmse:6.59578
# [635]	validation-rmse:6.59569
# [636]	validation-rmse:6.59559
# [637]	validation-rmse:6.59555
# [638]	validation-rmse:6.59550
# [639]	validation-rmse:6.59544
# [640]	validation-rmse:6.59540
# [641]	validation-rmse:6.59526
# [642]	validation-rmse:6.59524
# [643]	validation-rmse:6.59513
# [644]	validation-rmse:6.59503
# [645]	validation-rmse:6.59495
# [646]	validation-rmse:6.59473
# [647]	validation-rmse:6.59463
# [648]	validation-rmse:6.59458
# [649]	validation-rmse:6.59457
# [650]	validation-rmse:6.59456
# [651]	validation-rmse:6.59450
# [652]	validation-rmse:6.59439
# [653]	validation-rmse:6.59439
# [654]	validation-rmse:6.59436
# [655]	validation-rmse:6.59430
# [656]	validation-rmse:6.59430
# [657]	validation-rmse:6.59420
# [658]	validation-rmse:6.59412
# [659]	validation-rmse:6.59397
# [660]	validation-rmse:6.59382
# [661]	validation-rmse:6.59374
# [662]	validation-rmse:6.59362
# [663]	validation-rmse:6.59331
# [664]	validation-rmse:6.59322
# [665]	validation-rmse:6.59319
# [666]	validation-rmse:6.59317
# [667]	validation-rmse:6.59305
# [668]	validation-rmse:6.59302
# [669]	validation-rmse:6.59291
# [670]	validation-rmse:6.59279
# [671]	validation-rmse:6.59273
# [672]	validation-rmse:6.59269
# [673]	validation-rmse:6.59265
# [674]	validation-rmse:6.59261
# [675]	validation-rmse:6.59259
# [676]	validation-rmse:6.59249
# [677]	validation-rmse:6.59242
# [678]	validation-rmse:6.59233
# [679]	validation-rmse:6.59227
# [680]	validation-rmse:6.59220
# [681]	validation-rmse:6.59215
# [682]	validation-rmse:6.59215
# [683]	validation-rmse:6.59201
# [684]	validation-rmse:6.59191
# [685]	validation-rmse:6.59176
# [686]	validation-rmse:6.59170
# [687]	validation-rmse:6.59163
# [688]	validation-rmse:6.59148
# [689]	validation-rmse:6.59135
# [690]	validation-rmse:6.59123
# [691]	validation-rmse:6.59115
# [692]	validation-rmse:6.59112
# [693]	validation-rmse:6.59106
# [694]	validation-rmse:6.59098
# [695]	validation-rmse:6.59099
# [696]	validation-rmse:6.59066
# [697]	validation-rmse:6.59057
# [698]	validation-rmse:6.59052
# [699]	validation-rmse:6.59042
# [700]	validation-rmse:6.59035
# [701]	validation-rmse:6.59031
# [702]	validation-rmse:6.59015
# [703]	validation-rmse:6.59007
# [704]	validation-rmse:6.59006
# [705]	validation-rmse:6.59003
# [706]	validation-rmse:6.58995
# [707]	validation-rmse:6.58995
# [708]	validation-rmse:6.58990
# [709]	validation-rmse:6.58976
# [710]	validation-rmse:6.58973
# [711]	validation-rmse:6.58975
# [712]	validation-rmse:6.58962
# [713]	validation-rmse:6.58946
# [714]	validation-rmse:6.58932
# [715]	validation-rmse:6.58929
# [716]	validation-rmse:6.58925
# [717]	validation-rmse:6.58924
# [718]	validation-rmse:6.58912
# [719]	validation-rmse:6.58909
# [720]	validation-rmse:6.58898
# [721]	validation-rmse:6.58891
# [722]	validation-rmse:6.58879
# [723]	validation-rmse:6.58863
# [724]	validation-rmse:6.58860
# [725]	validation-rmse:6.58855
# [726]	validation-rmse:6.58840
# [727]	validation-rmse:6.58833
# [728]	validation-rmse:6.58825
# [729]	validation-rmse:6.58821
# [730]	validation-rmse:6.58817
# [731]	validation-rmse:6.58808
# [732]	validation-rmse:6.58807
# [733]	validation-rmse:6.58798
# [734]	validation-rmse:6.58798
# [735]	validation-rmse:6.58793
# [736]	validation-rmse:6.58789
# [737]	validation-rmse:6.58775
# [738]	validation-rmse:6.58766
# [739]	validation-rmse:6.58753
# [740]	validation-rmse:6.58752
# [741]	validation-rmse:6.58754
# [742]	validation-rmse:6.58742
# [743]	validation-rmse:6.58736
# [744]	validation-rmse:6.58708
# [745]	validation-rmse:6.58694
# [746]	validation-rmse:6.58686
# [747]	validation-rmse:6.58679
# [748]	validation-rmse:6.58669
# [749]	validation-rmse:6.58668
# [750]	validation-rmse:6.58658
# [751]	validation-rmse:6.58659
# [752]	validation-rmse:6.58646
# [753]	validation-rmse:6.58638
# [754]	validation-rmse:6.58632
# [755]	validation-rmse:6.58629
# [756]	validation-rmse:6.58604
# [757]	validation-rmse:6.58599
# [758]	validation-rmse:6.58597
# [759]	validation-rmse:6.58586
# [760]	validation-rmse:6.58561
# [761]	validation-rmse:6.58552
# [762]	validation-rmse:6.58547
# [763]	validation-rmse:6.58541
# [764]	validation-rmse:6.58541
# [765]	validation-rmse:6.58536
# [766]	validation-rmse:6.58532
# [767]	validation-rmse:6.58527
# [768]	validation-rmse:6.58522
# [769]	validation-rmse:6.58523
# [770]	validation-rmse:6.58521
# [771]	validation-rmse:6.58519
# [772]	validation-rmse:6.58521
# [773]	validation-rmse:6.58517
# [774]	validation-rmse:6.58510
# [775]	validation-rmse:6.58505
# [776]	validation-rmse:6.58506
# [777]	validation-rmse:6.58504
# [778]	validation-rmse:6.58499
# [779]	validation-rmse:6.58492
# [780]	validation-rmse:6.58482
# [781]	validation-rmse:6.58475
# [782]	validation-rmse:6.58468
# [783]	validation-rmse:6.58462
# [784]	validation-rmse:6.58460
# [785]	validation-rmse:6.58453
# [786]	validation-rmse:6.58451
# [787]	validation-rmse:6.58444
# [788]	validation-rmse:6.58434
# [789]	validation-rmse:6.58429
# [790]	validation-rmse:6.58425
# [791]	validation-rmse:6.58421
# [792]	validation-rmse:6.58420
# [793]	validation-rmse:6.58413
# [794]	validation-rmse:6.58410
# [795]	validation-rmse:6.58405
# [796]	validation-rmse:6.58395
# [797]	validation-rmse:6.58388
# [798]	validation-rmse:6.58381
# [799]	validation-rmse:6.58372
# [800]	validation-rmse:6.58367
# [801]	validation-rmse:6.58362
# [802]	validation-rmse:6.58337
# [803]	validation-rmse:6.58331
# [804]	validation-rmse:6.58318
# [805]	validation-rmse:6.58311
# [806]	validation-rmse:6.58303
# [807]	validation-rmse:6.58294
# [808]	validation-rmse:6.58277
# [809]	validation-rmse:6.58257
# [810]	validation-rmse:6.58249
# [811]	validation-rmse:6.58246
# [812]	validation-rmse:6.58236
# [813]	validation-rmse:6.58234
# [814]	validation-rmse:6.58235
# [815]	validation-rmse:6.58216
# [816]	validation-rmse:6.58191
# [817]	validation-rmse:6.58185
# [818]	validation-rmse:6.58171
# [819]	validation-rmse:6.58172
# [820]	validation-rmse:6.58158
# [821]	validation-rmse:6.58159
# [822]	validation-rmse:6.58157
# [823]	validation-rmse:6.58153
# [824]	validation-rmse:6.58151
# [825]	validation-rmse:6.58152
# [826]	validation-rmse:6.58149
# [827]	validation-rmse:6.58146
# [828]	validation-rmse:6.58144
# [829]	validation-rmse:6.58143
# [830]	validation-rmse:6.58140
# [831]	validation-rmse:6.58135
# [832]	validation-rmse:6.58127
# [833]	validation-rmse:6.58121
# [834]	validation-rmse:6.58112
# [835]	validation-rmse:6.58104
# [836]	validation-rmse:6.58101
# [837]	validation-rmse:6.58094
# [838]	validation-rmse:6.58090
# [839]	validation-rmse:6.58091
# [840]	validation-rmse:6.58082
# [841]	validation-rmse:6.58070
# [842]	validation-rmse:6.58066
# [843]	validation-rmse:6.58066
# [844]	validation-rmse:6.58048
# [845]	validation-rmse:6.58037
# [846]	validation-rmse:6.58006
# [847]	validation-rmse:6.58001
# [848]	validation-rmse:6.57985
# [849]	validation-rmse:6.57957
# [850]	validation-rmse:6.57949
# [851]	validation-rmse:6.57941
# [852]	validation-rmse:6.57932
# [853]	validation-rmse:6.57927
# [854]	validation-rmse:6.57918
# [855]	validation-rmse:6.57913
# [856]	validation-rmse:6.57899
# [857]	validation-rmse:6.57888
# [858]	validation-rmse:6.57874
# [859]	validation-rmse:6.57869
# [860]	validation-rmse:6.57869
# [861]	validation-rmse:6.57865
# [862]	validation-rmse:6.57863
# [863]	validation-rmse:6.57850
# [864]	validation-rmse:6.57841
# [865]	validation-rmse:6.57836
# [866]	validation-rmse:6.57833
# [867]	validation-rmse:6.57833
# [868]	validation-rmse:6.57823
# [869]	validation-rmse:6.57818
# [870]	validation-rmse:6.57814
# [871]	validation-rmse:6.57811
# ...
# [151]	validation-rmse:6.55617
# [152]	validation-rmse:6.55583
# [153]	validation-rmse:6.55571
# [154]	validation-rmse:6.55550
# [155]	validation-rmse:6.55538
# [156]	validation-rmse:6.55517
# [157]	validation-rmse:6.55516
# [158]	validation-rmse:6.55499
# [159]	validation-rmse:6.55469
# [160]	validation-rmse:6.55451
# [161]	validation-rmse:6.55435
# [162]	validation-rmse:6.55424
# [163]	validation-rmse:6.55409
# [164]	validation-rmse:6.55397
# [165]	validation-rmse:6.55386
# [166]	validation-rmse:6.55360
# [167]	validation-rmse:6.55346
# [168]	validation-rmse:6.55323
# [169]	validation-rmse:6.55310
# [170]	validation-rmse:6.55290
# [171]	validation-rmse:6.55271
# [172]	validation-rmse:6.55253
# [173]	validation-rmse:6.55246
# [174]	validation-rmse:6.55239
# [175]	validation-rmse:6.55227
# [176]	validation-rmse:6.55213
# [177]	validation-rmse:6.55198
# [178]	validation-rmse:6.55169
# [179]	validation-rmse:6.55155
# [180]	validation-rmse:6.55145
# [181]	validation-rmse:6.55129
# [182]	validation-rmse:6.55109
# [183]	validation-rmse:6.55095
# [184]	validation-rmse:6.55086
# [185]	validation-rmse:6.55066
# [186]	validation-rmse:6.55056
# [187]	validation-rmse:6.55036
# [188]	validation-rmse:6.55027
# [189]	validation-rmse:6.55005
# [190]	validation-rmse:6.54999
# [191]	validation-rmse:6.54985
# [192]	validation-rmse:6.54969
# [193]	validation-rmse:6.54955
# [194]	validation-rmse:6.54947
# [195]	validation-rmse:6.54946
# [196]	validation-rmse:6.54936
# [197]	validation-rmse:6.54933
# [198]	validation-rmse:6.54914
# [199]	validation-rmse:6.54900
# [200]	validation-rmse:6.54890
# [201]	validation-rmse:6.54870
# [202]	validation-rmse:6.54857
# [203]	validation-rmse:6.54844
# [204]	validation-rmse:6.54832
# [205]	validation-rmse:6.54821
# [206]	validation-rmse:6.54818
# [207]	validation-rmse:6.54805
# [208]	validation-rmse:6.54795
# [209]	validation-rmse:6.54782
# [210]	validation-rmse:6.54768
# [211]	validation-rmse:6.54758
# [212]	validation-rmse:6.54748
# [213]	validation-rmse:6.54730
# [214]	validation-rmse:6.54725
# [215]	validation-rmse:6.54720
# [216]	validation-rmse:6.54718
# [217]	validation-rmse:6.54703
# [218]	validation-rmse:6.54698
# [219]	validation-rmse:6.54680
# [220]	validation-rmse:6.54662
# [221]	validation-rmse:6.54656
# [222]	validation-rmse:6.54649
# [223]	validation-rmse:6.54622
# [224]	validation-rmse:6.54616
# [225]	validation-rmse:6.54603
# [226]	validation-rmse:6.54579
# [227]	validation-rmse:6.54568
# [228]	validation-rmse:6.54552
# [229]	validation-rmse:6.54537
# [230]	validation-rmse:6.54530
# [231]	validation-rmse:6.54498
# [232]	validation-rmse:6.54491
# [233]	validation-rmse:6.54485
# [234]	validation-rmse:6.54468
# [235]	validation-rmse:6.54463
# [236]	validation-rmse:6.54456
# [237]	validation-rmse:6.54448
# [238]	validation-rmse:6.54450
# [239]	validation-rmse:6.54442
# [240]	validation-rmse:6.54409
# [241]	validation-rmse:6.54402
# [242]	validation-rmse:6.54396
# [243]	validation-rmse:6.54389
# [244]	validation-rmse:6.54364
# [245]	validation-rmse:6.54351
# [246]	validation-rmse:6.54348
# [247]	validation-rmse:6.54318
# [248]	validation-rmse:6.54300
# [249]	validation-rmse:6.54278
# [250]	validation-rmse:6.54272
# [251]	validation-rmse:6.54253
# [252]	validation-rmse:6.54241
# [253]	validation-rmse:6.54213
# [254]	validation-rmse:6.54207
# [255]	validation-rmse:6.54199
# [256]	validation-rmse:6.54192
# [257]	validation-rmse:6.54184
# [258]	validation-rmse:6.54174
# [259]	validation-rmse:6.54168
# [260]	validation-rmse:6.54163
# [261]	validation-rmse:6.54147
# [262]	validation-rmse:6.54138
# [263]	validation-rmse:6.54137
#   8%|▊         | 4/50 [03:50<44:16, 57.74s/trial, best loss: 6.319109466532286]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 12
#       1 # search space to find the best hyperparameter
#       2 search_space = {
#       3     'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
#       4     'learning_rate': hp.loguniform('learning_rate', -3, 0),
#    (...)
#       9     'seed': 42
#      10 }
# ---> 12 best_result = fmin(
#      13     fn = objective,
#      14     space = search_space,
#      15     algo = tpe.suggest,
#      16     max_evals = 50,
#      17     trials = Trials()
#      18 )
#      20 print(best_result)
#
# File ~/anaconda3/envs/mlops-env/lib/python3.11/site-packages/hyperopt/fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File ~/anaconda3/envs/mlops-env/lib/python3.11/site-packages/hyperopt/base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File ~/anaconda3/envs/mlops-env/lib/python3.11/site-packages/hyperopt/fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File ~/anaconda3/envs/mlops-env/lib/python3.11/site-packages/hyperopt/fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File ~/anaconda3/envs/mlops-env/lib/python3.11/site-packages/hyperopt/fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File ~/anaconda3/envs/mlops-env/lib/python3.11/site-packages/hyperopt/fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File ~/anaconda3/envs/mlops-env/lib/python3.11/site-packages/hyperopt/base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[10], line 10, in objective(params)
#       7 # log parameter
#       8 mlflow.log_params(params)
# ---> 10 booster = xgb.train(
#      11     params = params,
#      12     dtrain = train,
#      13     num_boost_round = 1000,
#      14     evals = [(valid, 'validation')],
#      15     early_stopping_rounds = 50
#      16 )
#      18 y_pred = booster.predict(valid)
#      19 rmse = root_mean_squared_error(y_val, y_pred)
#
# File ~/anaconda3/envs/mlops-env/lib/python3.11/site-packages/xgboost/core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File ~/anaconda3/envs/mlops-env/lib/python3.11/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, i, obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File ~/anaconda3/envs/mlops-env/lib/python3.11/site-packages/xgboost/core.py:2051, in Booster.update(self, dtrain, iteration, fobj)
#    2047 self._assign_dmatrix_features(dtrain)
#    2049 if fobj is None:
#    2050     _check_call(
# -> 2051         _LIB.XGBoosterUpdateOneIter(
#    2052             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2053         )
#    2054     )
#    2055 else:
#    2056     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
# use best parameter to train the model
params = {
    'learning_rate': 0.6653267087715755,
    'max_depth': 20,
    'min_child_weight': 19.965812980250803,
    'objective': 'reg:squarederror',
    'reg_alpha': 0.18289424399274412,
    'reg_lambda': 0.0969372299406269,
    'seed': 42
}

# enable autolog
mlflow.xgboost.autolog(disable = False)

with mlflow.start_run():
    booster = xgb.train(
        params = params,
        dtrain = train,
        num_boost_round = 1000,
        evals = [(valid, 'validation')],
        early_stopping_rounds = 50
    )
# Out:
# [0]	validation-rmse:7.75328
# [1]	validation-rmse:6.94322
# [2]	validation-rmse:6.79259
# [3]	validation-rmse:6.73933
# [4]	validation-rmse:6.71455
# [5]	validation-rmse:6.70595
# [6]	validation-rmse:6.70304
# [7]	validation-rmse:6.70092
# [8]	validation-rmse:6.69706
# [9]	validation-rmse:6.69438
# [10]	validation-rmse:6.69379
# [11]	validation-rmse:6.69064
# [12]	validation-rmse:6.68937
# [13]	validation-rmse:6.68716
# [14]	validation-rmse:6.68538
# [15]	validation-rmse:6.68556
# [16]	validation-rmse:6.68103
# [17]	validation-rmse:6.67992
# [18]	validation-rmse:6.67886
# [19]	validation-rmse:6.67828
# [20]	validation-rmse:6.67755
# [21]	validation-rmse:6.67640
# [22]	validation-rmse:6.67589
# [23]	validation-rmse:6.67511
# [24]	validation-rmse:6.67438
# [25]	validation-rmse:6.67411
# [26]	validation-rmse:6.67320
# [27]	validation-rmse:6.67253
# [28]	validation-rmse:6.67236
# [29]	validation-rmse:6.67170
# [30]	validation-rmse:6.67115
# [31]	validation-rmse:6.67068
# [32]	validation-rmse:6.67050
# [33]	validation-rmse:6.67022
# [34]	validation-rmse:6.67016
# [35]	validation-rmse:6.67046
# [36]	validation-rmse:6.66985
# [37]	validation-rmse:6.66962
# [38]	validation-rmse:6.66945
# [39]	validation-rmse:6.66787
# [40]	validation-rmse:6.66678
# [41]	validation-rmse:6.66588
# [42]	validation-rmse:6.66562
# [43]	validation-rmse:6.66521
# [44]	validation-rmse:6.66484
# [45]	validation-rmse:6.66444
# [46]	validation-rmse:6.66389
# [47]	validation-rmse:6.66206
# [48]	validation-rmse:6.66164
# [49]	validation-rmse:6.66141
# [50]	validation-rmse:6.66129
# [51]	validation-rmse:6.66045
# [52]	validation-rmse:6.66060
# [53]	validation-rmse:6.66004
# [54]	validation-rmse:6.65983
# [55]	validation-rmse:6.65921
# [56]	validation-rmse:6.65923
# [57]	validation-rmse:6.65879
# [58]	validation-rmse:6.65867
# [59]	validation-rmse:6.65825
# [60]	validation-rmse:6.65790
# [61]	validation-rmse:6.65761
# [62]	validation-rmse:6.65713
# [63]	validation-rmse:6.65715
# [64]	validation-rmse:6.65700
# [65]	validation-rmse:6.65690
# [66]	validation-rmse:6.65676
# [67]	validation-rmse:6.65621
# [68]	validation-rmse:6.65624
# [69]	validation-rmse:6.65597
# [70]	validation-rmse:6.65592
# [71]	validation-rmse:6.65561
# [72]	validation-rmse:6.65527
# [73]	validation-rmse:6.65503
# [74]	validation-rmse:6.65470
# [75]	validation-rmse:6.65466
# [76]	validation-rmse:6.65474
# [77]	validation-rmse:6.65450
# [78]	validation-rmse:6.65440
# [79]	validation-rmse:6.65360
# [80]	validation-rmse:6.65351
# [81]	validation-rmse:6.65336
# [82]	validation-rmse:6.65299
# [83]	validation-rmse:6.65300
# [84]	validation-rmse:6.65285
# [85]	validation-rmse:6.65277
# [86]	validation-rmse:6.65258
# [87]	validation-rmse:6.65257
# [88]	validation-rmse:6.65244
# [89]	validation-rmse:6.65211
# [90]	validation-rmse:6.65217
# [91]	validation-rmse:6.65174
# [92]	validation-rmse:6.65156
# [93]	validation-rmse:6.65158
# [94]	validation-rmse:6.65154
# [95]	validation-rmse:6.65162
# [96]	validation-rmse:6.65148
# [97]	validation-rmse:6.65116
# [98]	validation-rmse:6.65112
# [99]	validation-rmse:6.65109
# [100]	validation-rmse:6.65106
# [101]	validation-rmse:6.65100
# [102]	validation-rmse:6.65083
# [103]	validation-rmse:6.65070
# [104]	validation-rmse:6.65041
# [105]	validation-rmse:6.65012
# [106]	validation-rmse:6.65024
# [107]	validation-rmse:6.64990
# [108]	validation-rmse:6.64968
# [109]	validation-rmse:6.64979
# [110]	validation-rmse:6.64958
# [111]	validation-rmse:6.64948
# [112]	validation-rmse:6.64954
# [113]	validation-rmse:6.64942
# [114]	validation-rmse:6.64927
# [115]	validation-rmse:6.64929
# [116]	validation-rmse:6.64912
# [117]	validation-rmse:6.64870
# [118]	validation-rmse:6.64850
# [119]	validation-rmse:6.64809
# [120]	validation-rmse:6.64794
# [121]	validation-rmse:6.64737
# [122]	validation-rmse:6.64724
# [123]	validation-rmse:6.64673
# [124]	validation-rmse:6.64646
# [125]	validation-rmse:6.64643
# [126]	validation-rmse:6.64666
# [127]	validation-rmse:6.64657
# [128]	validation-rmse:6.64627
# [129]	validation-rmse:6.64609
# [130]	validation-rmse:6.64593
# [131]	validation-rmse:6.64593
# [132]	validation-rmse:6.64595
# [133]	validation-rmse:6.64583
# [134]	validation-rmse:6.64530
# [135]	validation-rmse:6.64533
# [136]	validation-rmse:6.64544
# [137]	validation-rmse:6.64465
# [138]	validation-rmse:6.64534
# [139]	validation-rmse:6.64503
# [140]	validation-rmse:6.64510
# [141]	validation-rmse:6.64486
# [142]	validation-rmse:6.64492
# [143]	validation-rmse:6.64480
# [144]	validation-rmse:6.64478
# [145]	validation-rmse:6.64477
# [146]	validation-rmse:6.64439
# [147]	validation-rmse:6.64411
# [148]	validation-rmse:6.64411
# [149]	validation-rmse:6.64413
# [150]	validation-rmse:6.64405
# [151]	validation-rmse:6.64400
# [152]	validation-rmse:6.64377
# [153]	validation-rmse:6.64388
# [154]	validation-rmse:6.64385
# [155]	validation-rmse:6.64359
# [156]	validation-rmse:6.64336
# [157]	validation-rmse:6.64325
# [158]	validation-rmse:6.64359
# [159]	validation-rmse:6.64310
# [160]	validation-rmse:6.64286
# [161]	validation-rmse:6.64283
# [162]	validation-rmse:6.64287
# [163]	validation-rmse:6.64258
# [164]	validation-rmse:6.64265
# [165]	validation-rmse:6.64236
# [166]	validation-rmse:6.64250
# [167]	validation-rmse:6.64246
# [168]	validation-rmse:6.64144
# [169]	validation-rmse:6.64231
# [170]	validation-rmse:6.64195
# [171]	validation-rmse:6.64192
# [172]	validation-rmse:6.64189
# [173]	validation-rmse:6.64205
# [174]	validation-rmse:6.64163
# [175]	validation-rmse:6.64177
# [176]	validation-rmse:6.64137
# [177]	validation-rmse:6.64123
# [178]	validation-rmse:6.64123
# [179]	validation-rmse:6.64120
# [180]	validation-rmse:6.64112
# [181]	validation-rmse:6.64098
# [182]	validation-rmse:6.64096
# [183]	validation-rmse:6.64082
# [184]	validation-rmse:6.64093
# [185]	validation-rmse:6.64054
# [186]	validation-rmse:6.64067
# [187]	validation-rmse:6.64045
# [188]	validation-rmse:6.64048
# [189]	validation-rmse:6.64058
# [190]	validation-rmse:6.64046
# [191]	validation-rmse:6.64034
# [192]	validation-rmse:6.64021
# [193]	validation-rmse:6.64026
# [194]	validation-rmse:6.64012
# [195]	validation-rmse:6.64025
# [196]	validation-rmse:6.64006
# [197]	validation-rmse:6.64023
# [198]	validation-rmse:6.64006
# [199]	validation-rmse:6.64001
# [200]	validation-rmse:6.63991
# [201]	validation-rmse:6.63987
# [202]	validation-rmse:6.63998
# [203]	validation-rmse:6.63933
# [204]	validation-rmse:6.63928
# [205]	validation-rmse:6.63942
# [206]	validation-rmse:6.63935
# [207]	validation-rmse:6.63932
# [208]	validation-rmse:6.63949
# [209]	validation-rmse:6.63937
# [210]	validation-rmse:6.63928
# [211]	validation-rmse:6.63930
# [212]	validation-rmse:6.63860
# [213]	validation-rmse:6.63890
# [214]	validation-rmse:6.63884
# [215]	validation-rmse:6.63903
# [216]	validation-rmse:6.63890
# [217]	validation-rmse:6.63862
# [218]	validation-rmse:6.63822
# [219]	validation-rmse:6.63815
# [220]	validation-rmse:6.63837
# [221]	validation-rmse:6.63852
# [222]	validation-rmse:6.63759
# [223]	validation-rmse:6.63794
# [224]	validation-rmse:6.63767
# [225]	validation-rmse:6.63791
# [226]	validation-rmse:6.63748
# [227]	validation-rmse:6.63790
# [228]	validation-rmse:6.63795
# [229]	validation-rmse:6.63786
# [230]	validation-rmse:6.63771
# [231]	validation-rmse:6.63764
# [232]	validation-rmse:6.63753
# [233]	validation-rmse:6.63744
# [234]	validation-rmse:6.63732
# [235]	validation-rmse:6.63722
# [236]	validation-rmse:6.63708
# [237]	validation-rmse:6.63733
# [238]	validation-rmse:6.63719
# [239]	validation-rmse:6.63716
# [240]	validation-rmse:6.63720
# [241]	validation-rmse:6.63708
# [242]	validation-rmse:6.63721
# [243]	validation-rmse:6.63715
# [244]	validation-rmse:6.63704
# [245]	validation-rmse:6.63694
# [246]	validation-rmse:6.63650
# [247]	validation-rmse:6.63668
# [248]	validation-rmse:6.63652
# [249]	validation-rmse:6.63629
# [250]	validation-rmse:6.63622
# [251]	validation-rmse:6.63619
# [252]	validation-rmse:6.63590
# [253]	validation-rmse:6.63591
# [254]	validation-rmse:6.63572
# [255]	validation-rmse:6.63572
# [256]	validation-rmse:6.63576
# [257]	validation-rmse:6.63569
# [258]	validation-rmse:6.63568
# [259]	validation-rmse:6.63567
# [260]	validation-rmse:6.63550
# [261]	validation-rmse:6.63553
# [262]	validation-rmse:6.63547
# [263]	validation-rmse:6.63539
# [264]	validation-rmse:6.63534
# [265]	validation-rmse:6.63521
# [266]	validation-rmse:6.63517
# [267]	validation-rmse:6.63507
# [268]	validation-rmse:6.63508
# [269]	validation-rmse:6.63422
# [270]	validation-rmse:6.63430
# [271]	validation-rmse:6.63448
# [272]	validation-rmse:6.63432
# [273]	validation-rmse:6.63432
# [274]	validation-rmse:6.63439
# [275]	validation-rmse:6.63432
# [276]	validation-rmse:6.63433
# [277]	validation-rmse:6.63437
# [278]	validation-rmse:6.63444
# [279]	validation-rmse:6.63435
# [280]	validation-rmse:6.63428
# [281]	validation-rmse:6.63422
# [282]	validation-rmse:6.63413
# [283]	validation-rmse:6.63399
# [284]	validation-rmse:6.63396
# [285]	validation-rmse:6.63382
# [286]	validation-rmse:6.63386
# [287]	validation-rmse:6.63330
# [288]	validation-rmse:6.63352
# [289]	validation-rmse:6.63312
# [290]	validation-rmse:6.63333
# [291]	validation-rmse:6.63321
# [292]	validation-rmse:6.63324
# [293]	validation-rmse:6.63317
# [294]	validation-rmse:6.63314
# [295]	validation-rmse:6.63305
# [296]	validation-rmse:6.63302
# [297]	validation-rmse:6.63302
# [298]	validation-rmse:6.63299
# [299]	validation-rmse:6.63298
# [300]	validation-rmse:6.63295
# [301]	validation-rmse:6.63287
# [302]	validation-rmse:6.63259
# [303]	validation-rmse:6.63280
# [304]	validation-rmse:6.63279
# [305]	validation-rmse:6.63278
# [306]	validation-rmse:6.63273
# [307]	validation-rmse:6.63277
# [308]	validation-rmse:6.63268
# [309]	validation-rmse:6.63267
# [310]	validation-rmse:6.63249
# [311]	validation-rmse:6.63240
# [312]	validation-rmse:6.63229
# [313]	validation-rmse:6.63233
# [314]	validation-rmse:6.63220
# [315]	validation-rmse:6.63205
# [316]	validation-rmse:6.63196
# [317]	validation-rmse:6.63198
# [318]	validation-rmse:6.63189
# [319]	validation-rmse:6.63191
# [320]	validation-rmse:6.63180
# [321]	validation-rmse:6.63183
# [322]	validation-rmse:6.63166
# [323]	validation-rmse:6.63172
# [324]	validation-rmse:6.63156
# [325]	validation-rmse:6.63164
# [326]	validation-rmse:6.63166
# [327]	validation-rmse:6.63144
# [328]	validation-rmse:6.63148
# [329]	validation-rmse:6.63150
# [330]	validation-rmse:6.63148
# [331]	validation-rmse:6.63130
# [332]	validation-rmse:6.63130
# [333]	validation-rmse:6.63137
# [334]	validation-rmse:6.63127
# [335]	validation-rmse:6.63143
# [336]	validation-rmse:6.63138
# [337]	validation-rmse:6.63149
# [338]	validation-rmse:6.63151
# [339]	validation-rmse:6.63085
# [340]	validation-rmse:6.63085
# [341]	validation-rmse:6.63123
# [342]	validation-rmse:6.63124
# [343]	validation-rmse:6.63121
# [344]	validation-rmse:6.63120
# [345]	validation-rmse:6.63120
# [346]	validation-rmse:6.63115
# [347]	validation-rmse:6.63110
# [348]	validation-rmse:6.63094
# [349]	validation-rmse:6.63106
# [350]	validation-rmse:6.63102
# [351]	validation-rmse:6.63106
# [352]	validation-rmse:6.63105
# [353]	validation-rmse:6.63127
# [354]	validation-rmse:6.63093
# [355]	validation-rmse:6.63085
# [356]	validation-rmse:6.63090
# [357]	validation-rmse:6.63086
# [358]	validation-rmse:6.63028
# [359]	validation-rmse:6.63029
# [360]	validation-rmse:6.63036
# [361]	validation-rmse:6.63004
# [362]	validation-rmse:6.62982
# [363]	validation-rmse:6.62985
# [364]	validation-rmse:6.62981
# [365]	validation-rmse:6.62977
# [366]	validation-rmse:6.62979
# [367]	validation-rmse:6.62967
# [368]	validation-rmse:6.62974
# [369]	validation-rmse:6.62954
# [370]	validation-rmse:6.62982
# [371]	validation-rmse:6.62970
# [372]	validation-rmse:6.62981
# [373]	validation-rmse:6.62981
# [374]	validation-rmse:6.63005
# [375]	validation-rmse:6.62977
# [376]	validation-rmse:6.62970
# [377]	validation-rmse:6.62990
# [378]	validation-rmse:6.62977
# [379]	validation-rmse:6.62988
# [380]	validation-rmse:6.62981
# [381]	validation-rmse:6.62994
# [382]	validation-rmse:6.62998
# [383]	validation-rmse:6.62975
# [384]	validation-rmse:6.62975
# [385]	validation-rmse:6.62976
# [386]	validation-rmse:6.62965
# [387]	validation-rmse:6.62957
# [388]	validation-rmse:6.62968
# [389]	validation-rmse:6.62970
# [390]	validation-rmse:6.62964
# [391]	validation-rmse:6.62972
# [392]	validation-rmse:6.62977
# [393]	validation-rmse:6.62946
# [394]	validation-rmse:6.62954
# [395]	validation-rmse:6.62956
# [396]	validation-rmse:6.62964
# [397]	validation-rmse:6.62951
# [398]	validation-rmse:6.62976
# [399]	validation-rmse:6.62983
# [400]	validation-rmse:6.63003
# [401]	validation-rmse:6.62972
# [402]	validation-rmse:6.62991
# [403]	validation-rmse:6.62962
# [404]	validation-rmse:6.62953
# [405]	validation-rmse:6.62964
# [406]	validation-rmse:6.62971
# [407]	validation-rmse:6.62927
# [408]	validation-rmse:6.62928
# [409]	validation-rmse:6.62928
# [410]	validation-rmse:6.62934
# [411]	validation-rmse:6.62933
# [412]	validation-rmse:6.62929
# [413]	validation-rmse:6.62912
# [414]	validation-rmse:6.62896
# [415]	validation-rmse:6.62935
# [416]	validation-rmse:6.62939
# [417]	validation-rmse:6.62949
# [418]	validation-rmse:6.62935
# [419]	validation-rmse:6.62931
# [420]	validation-rmse:6.62932
# [421]	validation-rmse:6.62920
# [422]	validation-rmse:6.62924
# [423]	validation-rmse:6.62929
# [424]	validation-rmse:6.62936
# [425]	validation-rmse:6.62932
# [426]	validation-rmse:6.62930
# [427]	validation-rmse:6.62930
# [428]	validation-rmse:6.62916
# [429]	validation-rmse:6.62966
# [430]	validation-rmse:6.62972
# [431]	validation-rmse:6.62954
# [432]	validation-rmse:6.62943
# [433]	validation-rmse:6.62918
# [434]	validation-rmse:6.62912
# [435]	validation-rmse:6.62916
# [436]	validation-rmse:6.62923
# [437]	validation-rmse:6.62915
# [438]	validation-rmse:6.62913
# [439]	validation-rmse:6.62921
# [440]	validation-rmse:6.62910
# [441]	validation-rmse:6.62915
# [442]	validation-rmse:6.62930
# [443]	validation-rmse:6.62924
# [444]	validation-rmse:6.62920
# [445]	validation-rmse:6.62912
# [446]	validation-rmse:6.62909
# [447]	validation-rmse:6.62879
# [448]	validation-rmse:6.62881
# [449]	validation-rmse:6.62891
# [450]	validation-rmse:6.62909
# [451]	validation-rmse:6.62919
# [452]	validation-rmse:6.62907
# [453]	validation-rmse:6.62885
# [454]	validation-rmse:6.62873
# [455]	validation-rmse:6.62871
# [456]	validation-rmse:6.62860
# [457]	validation-rmse:6.62858
# [458]	validation-rmse:6.62858
# [459]	validation-rmse:6.62851
# [460]	validation-rmse:6.62861
# [461]	validation-rmse:6.62869
# [462]	validation-rmse:6.62878
# [463]	validation-rmse:6.62876
# [464]	validation-rmse:6.62881
# [465]	validation-rmse:6.62902
# [466]	validation-rmse:6.62840
# [467]	validation-rmse:6.62852
# [468]	validation-rmse:6.62901
# [469]	validation-rmse:6.62846
# [470]	validation-rmse:6.62866
# [471]	validation-rmse:6.62871
# [472]	validation-rmse:6.62820
# [473]	validation-rmse:6.62833
# [474]	validation-rmse:6.62859
# [475]	validation-rmse:6.62890
# [476]	validation-rmse:6.62834
# [477]	validation-rmse:6.62816
# [478]	validation-rmse:6.62826
# [479]	validation-rmse:6.62772
# [480]	validation-rmse:6.62778
# [481]	validation-rmse:6.62805
# [482]	validation-rmse:6.62800
# [483]	validation-rmse:6.62797
# [484]	validation-rmse:6.62815
# [485]	validation-rmse:6.62833
# [486]	validation-rmse:6.62817
# [487]	validation-rmse:6.62810
# [488]	validation-rmse:6.62798
# [489]	validation-rmse:6.62803
# [490]	validation-rmse:6.62811
# [491]	validation-rmse:6.62799
# [492]	validation-rmse:6.62820
# [493]	validation-rmse:6.62818
# [494]	validation-rmse:6.62801
# [495]	validation-rmse:6.62797
# [496]	validation-rmse:6.62818
# [497]	validation-rmse:6.62820
# [498]	validation-rmse:6.62776
# [499]	validation-rmse:6.62795
# [500]	validation-rmse:6.62768
# [501]	validation-rmse:6.62791
# [502]	validation-rmse:6.62780
# [503]	validation-rmse:6.62777
# [504]	validation-rmse:6.62778
# [505]	validation-rmse:6.62774
# [506]	validation-rmse:6.62774
# [507]	validation-rmse:6.62763
# [508]	validation-rmse:6.62764
# [509]	validation-rmse:6.62758
# [510]	validation-rmse:6.62764
# [511]	validation-rmse:6.62759
# [512]	validation-rmse:6.62758
# [513]	validation-rmse:6.62752
# [514]	validation-rmse:6.62751
# [515]	validation-rmse:6.62731
# [516]	validation-rmse:6.62734
# [517]	validation-rmse:6.62738
# [518]	validation-rmse:6.62742
# [519]	validation-rmse:6.62734
# [520]	validation-rmse:6.62738
# [521]	validation-rmse:6.62736
# [522]	validation-rmse:6.62737
# [523]	validation-rmse:6.62731
# [524]	validation-rmse:6.62724
# [525]	validation-rmse:6.62728
# [526]	validation-rmse:6.62731
# [527]	validation-rmse:6.62748
# [528]	validation-rmse:6.62733
# [529]	validation-rmse:6.62738
# [530]	validation-rmse:6.62741
# [531]	validation-rmse:6.62736
# [532]	validation-rmse:6.62729
# [533]	validation-rmse:6.62701
# [534]	validation-rmse:6.62725
# [535]	validation-rmse:6.62722
# [536]	validation-rmse:6.62731
# [537]	validation-rmse:6.62736
# [538]	validation-rmse:6.62725
# [539]	validation-rmse:6.62732
# [540]	validation-rmse:6.62708
# [541]	validation-rmse:6.62708
# [542]	validation-rmse:6.62697
# [543]	validation-rmse:6.62717
# [544]	validation-rmse:6.62723
# [545]	validation-rmse:6.62734
# [546]	validation-rmse:6.62730
# [547]	validation-rmse:6.62729
# [548]	validation-rmse:6.62689
# [549]	validation-rmse:6.62711
# [550]	validation-rmse:6.62712
# [551]	validation-rmse:6.62699
# [552]	validation-rmse:6.62723
# [553]	validation-rmse:6.62732
# [554]	validation-rmse:6.62722
# [555]	validation-rmse:6.62729
# [556]	validation-rmse:6.62729
# [557]	validation-rmse:6.62736
# [558]	validation-rmse:6.62764
# [559]	validation-rmse:6.62785
# [560]	validation-rmse:6.62792
# [561]	validation-rmse:6.62790
# [562]	validation-rmse:6.62778
# [563]	validation-rmse:6.62763
# [564]	validation-rmse:6.62762
# [565]	validation-rmse:6.62768
# [566]	validation-rmse:6.62768
# [567]	validation-rmse:6.62749
# [568]	validation-rmse:6.62739
# [569]	validation-rmse:6.62753
# [570]	validation-rmse:6.62749
# [571]	validation-rmse:6.62756
# [572]	validation-rmse:6.62705
# [573]	validation-rmse:6.62758
# [574]	validation-rmse:6.62761
# [575]	validation-rmse:6.62780
# [576]	validation-rmse:6.62721
# [577]	validation-rmse:6.62712
# [578]	validation-rmse:6.62739
# [579]	validation-rmse:6.62750
# [580]	validation-rmse:6.62755
# [581]	validation-rmse:6.62746
# [582]	validation-rmse:6.62756
# [583]	validation-rmse:6.62726
# [584]	validation-rmse:6.62725
# [585]	validation-rmse:6.62746
# [586]	validation-rmse:6.62764
# [587]	validation-rmse:6.62677
# [588]	validation-rmse:6.62711
# [589]	validation-rmse:6.62731
# [590]	validation-rmse:6.62739
# [591]	validation-rmse:6.62697
# [592]	validation-rmse:6.62738
# [593]	validation-rmse:6.62748
# [594]	validation-rmse:6.62771
# [595]	validation-rmse:6.62754
# [596]	validation-rmse:6.62754
# [597]	validation-rmse:6.62755
# [598]	validation-rmse:6.62749
# [599]	validation-rmse:6.62746
# [600]	validation-rmse:6.62744
# [601]	validation-rmse:6.62745
# [602]	validation-rmse:6.62746
# [603]	validation-rmse:6.62739
# [604]	validation-rmse:6.62737
# [605]	validation-rmse:6.62738
# [606]	validation-rmse:6.62729
# [607]	validation-rmse:6.62734
# [608]	validation-rmse:6.62733
# [609]	validation-rmse:6.62724
# [610]	validation-rmse:6.62738
# [611]	validation-rmse:6.62740
# [612]	validation-rmse:6.62683
# [613]	validation-rmse:6.62731
# [614]	validation-rmse:6.62718
# [615]	validation-rmse:6.62722
# [616]	validation-rmse:6.62722
# [617]	validation-rmse:6.62700
# [618]	validation-rmse:6.62695
# [619]	validation-rmse:6.62696
# [620]	validation-rmse:6.62689
# [621]	validation-rmse:6.62705
# [622]	validation-rmse:6.62697
# [623]	validation-rmse:6.62703
# [624]	validation-rmse:6.62710
# [625]	validation-rmse:6.62703
# [626]	validation-rmse:6.62703
# [627]	validation-rmse:6.62709
# [628]	validation-rmse:6.62702
# [629]	validation-rmse:6.62703
# [630]	validation-rmse:6.62700
# [631]	validation-rmse:6.62707
# [632]	validation-rmse:6.62705
# [633]	validation-rmse:6.62699
# [634]	validation-rmse:6.62715
# [635]	validation-rmse:6.62703
# [636]	validation-rmse:6.62694
# 2024/05/07 08:04:19 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.
# 2024/05/07 08:04:19 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/ubuntu/anaconda3/envs/mlops-env/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [08:04:19] WARNING: /workspace/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# 2024/05/07 08:04:21 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/ubuntu/anaconda3/envs/mlops-env/lib/python3.11/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2024/05/07 08:04:21 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/ubuntu/anaconda3/envs/mlops-env/lib/python3.11/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."

# %%
# disable log as want to use the best parameter to save model
mlflow.xgboost.autolog(disable = True)

with mlflow.start_run() as run:
    best_params = {
        'learning_rate': 0.09585355369315604,
        'max_depth': 30,
        'min_child_weight': 1.060597050922164,
        'objective': 'reg:squarederror',
        'reg_alpha': 0.018060244040060163,
        'reg_lambda': 0.011658731377413597,
        'seed': 42
    }

    # MLflow: store detail
    mlflow.set_tag("developer", "christopher")
    # MLflow: store detail
    mlflow.set_tag("model", "xgboost")
    # MLflow: store parameter
    mlflow.log_params(best_params)

    booster = xgb.train(
        params = best_params,
        dtrain = train,
        num_boost_round = 1000,
        evals = [(valid, 'validation')],
        early_stopping_rounds = 50
    )

    y_pred = booster.predict(valid)
    rmse = root_mean_squared_error(y_val, y_pred)

    # MLflow: RMSE metric
    mlflow.log_metric("rmse", rmse)

    # save preprocessor.b locally first
    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)

    # access locally then upload to MLflow
    mlflow.log_artifact("models/preprocessor.b", artifact_path = "preprocessor")

    # save model to MLflow model path
    mlflow.xgboost.log_model(booster, artifact_path = "model")

# obtain run id
run_id = run.info.run_id

# load model from MLflow
logged_model = f'runs:/{run_id}/model'
loaded_model = mlflow.pyfunc.load_model(logged_model)
xgboost_model = mlflow.xgboost.load_model(logged_model)

y_pred = xgboost_model.predict(valid)
y_pred
# Out:
# [0]	validation-rmse:11.44482
# [1]	validation-rmse:10.77202
# [2]	validation-rmse:10.18363
# [3]	validation-rmse:9.67396
# [4]	validation-rmse:9.23166
# [5]	validation-rmse:8.84808
# [6]	validation-rmse:8.51883
# [7]	validation-rmse:8.23597
# [8]	validation-rmse:7.99320
# [9]	validation-rmse:7.78709
# [10]	validation-rmse:7.61022
# [11]	validation-rmse:7.45952
# [12]	validation-rmse:7.33049
# [13]	validation-rmse:7.22098
# [14]	validation-rmse:7.12713
# [15]	validation-rmse:7.04752
# [16]	validation-rmse:6.98005
# [17]	validation-rmse:6.92232
# [18]	validation-rmse:6.87112
# [19]	validation-rmse:6.82740
# [20]	validation-rmse:6.78995
# [21]	validation-rmse:6.75792
# [22]	validation-rmse:6.72994
# [23]	validation-rmse:6.70547
# [24]	validation-rmse:6.68390
# [25]	validation-rmse:6.66421
# [26]	validation-rmse:6.64806
# [27]	validation-rmse:6.63280
# [28]	validation-rmse:6.61924
# [29]	validation-rmse:6.60773
# [30]	validation-rmse:6.59777
# [31]	validation-rmse:6.58875
# [32]	validation-rmse:6.58107
# [33]	validation-rmse:6.57217
# [34]	validation-rmse:6.56557
# [35]	validation-rmse:6.56003
# [36]	validation-rmse:6.55392
# [37]	validation-rmse:6.54924
# [38]	validation-rmse:6.54536
# [39]	validation-rmse:6.54187
# [40]	validation-rmse:6.53873
# [41]	validation-rmse:6.53518
# [42]	validation-rmse:6.53287
# [43]	validation-rmse:6.53048
# [44]	validation-rmse:6.52858
# [45]	validation-rmse:6.52703
# [46]	validation-rmse:6.52566
# [47]	validation-rmse:6.52419
# [48]	validation-rmse:6.52323
# [49]	validation-rmse:6.52265
# [50]	validation-rmse:6.52202
# [51]	validation-rmse:6.52036
# [52]	validation-rmse:6.52003
# [53]	validation-rmse:6.51962
# [54]	validation-rmse:6.51829
# [55]	validation-rmse:6.51712
# [56]	validation-rmse:6.51598
# [57]	validation-rmse:6.51517
# [58]	validation-rmse:6.51442
# [59]	validation-rmse:6.51357
# [60]	validation-rmse:6.51194
# [61]	validation-rmse:6.51127
# [62]	validation-rmse:6.51044
# [63]	validation-rmse:6.50930
# [64]	validation-rmse:6.50840
# [65]	validation-rmse:6.50731
# [66]	validation-rmse:6.50635
# [67]	validation-rmse:6.50566
# [68]	validation-rmse:6.50458
# [69]	validation-rmse:6.50339
# [70]	validation-rmse:6.50239
# [71]	validation-rmse:6.50137
# [72]	validation-rmse:6.50014
# [73]	validation-rmse:6.49940
# [74]	validation-rmse:6.49835
# [75]	validation-rmse:6.49782
# [76]	validation-rmse:6.49697
# [77]	validation-rmse:6.49628
# [78]	validation-rmse:6.49561
# [79]	validation-rmse:6.49495
# [80]	validation-rmse:6.49429
# [81]	validation-rmse:6.49371
# [82]	validation-rmse:6.49317
# [83]	validation-rmse:6.49248
# [84]	validation-rmse:6.49170
# [85]	validation-rmse:6.49080
# [86]	validation-rmse:6.49020
# [87]	validation-rmse:6.48927
# [88]	validation-rmse:6.48842
# [89]	validation-rmse:6.48717
# [90]	validation-rmse:6.48666
# [91]	validation-rmse:6.48608
# [92]	validation-rmse:6.48531
# [93]	validation-rmse:6.48457
# [94]	validation-rmse:6.48376
# [95]	validation-rmse:6.48304
# [96]	validation-rmse:6.48246
# [97]	validation-rmse:6.48113
# [98]	validation-rmse:6.48052
# [99]	validation-rmse:6.47984
# [100]	validation-rmse:6.47922
# [101]	validation-rmse:6.47886
# [102]	validation-rmse:6.47819
# [103]	validation-rmse:6.47742
# [104]	validation-rmse:6.47685
# [105]	validation-rmse:6.47643
# [106]	validation-rmse:6.47616
# [107]	validation-rmse:6.47583
# [108]	validation-rmse:6.47530
# [109]	validation-rmse:6.47479
# [110]	validation-rmse:6.47409
# [111]	validation-rmse:6.47339
# [112]	validation-rmse:6.47296
# [113]	validation-rmse:6.47250
# [114]	validation-rmse:6.47148
# [115]	validation-rmse:6.47089
# [116]	validation-rmse:6.47037
# [117]	validation-rmse:6.46947
# [118]	validation-rmse:6.46907
# [119]	validation-rmse:6.46840
# [120]	validation-rmse:6.46749
# [121]	validation-rmse:6.46701
# [122]	validation-rmse:6.46612
# [123]	validation-rmse:6.46538
# [124]	validation-rmse:6.46467
# [125]	validation-rmse:6.46413
# [126]	validation-rmse:6.46350
# [127]	validation-rmse:6.46265
# [128]	validation-rmse:6.46225
# [129]	validation-rmse:6.46169
# [130]	validation-rmse:6.46065
# [131]	validation-rmse:6.46022
# [132]	validation-rmse:6.45980
# [133]	validation-rmse:6.45918
# [134]	validation-rmse:6.45844
# [135]	validation-rmse:6.45802
# [136]	validation-rmse:6.45783
# [137]	validation-rmse:6.45746
# [138]	validation-rmse:6.45661
# [139]	validation-rmse:6.45619
# [140]	validation-rmse:6.45566
# [141]	validation-rmse:6.45554
# [142]	validation-rmse:6.45487
# [143]	validation-rmse:6.45461
# [144]	validation-rmse:6.45411
# [145]	validation-rmse:6.45325
# [146]	validation-rmse:6.45278
# [147]	validation-rmse:6.45215
# [148]	validation-rmse:6.45174
# [149]	validation-rmse:6.45146
# [150]	validation-rmse:6.45113
# [151]	validation-rmse:6.45076
# [152]	validation-rmse:6.45012
# [153]	validation-rmse:6.44965
# [154]	validation-rmse:6.44905
# [155]	validation-rmse:6.44872
# [156]	validation-rmse:6.44825
# [157]	validation-rmse:6.44792
# [158]	validation-rmse:6.44743
# [159]	validation-rmse:6.44671
# [160]	validation-rmse:6.44616
# [161]	validation-rmse:6.44562
# [162]	validation-rmse:6.44503
# [163]	validation-rmse:6.44434
# [164]	validation-rmse:6.44399
# [165]	validation-rmse:6.44339
# [166]	validation-rmse:6.44303
# [167]	validation-rmse:6.44260
# [168]	validation-rmse:6.44207
# [169]	validation-rmse:6.44173
# [170]	validation-rmse:6.44107
# [171]	validation-rmse:6.44068
# [172]	validation-rmse:6.44007
# [173]	validation-rmse:6.43964
# [174]	validation-rmse:6.43918
# [175]	validation-rmse:6.43883
# [176]	validation-rmse:6.43842
# [177]	validation-rmse:6.43803
# [178]	validation-rmse:6.43759
# [179]	validation-rmse:6.43714
# [180]	validation-rmse:6.43676
# [181]	validation-rmse:6.43644
# [182]	validation-rmse:6.43605
# [183]	validation-rmse:6.43571
# [184]	validation-rmse:6.43527
# [185]	validation-rmse:6.43489
# [186]	validation-rmse:6.43435
# [187]	validation-rmse:6.43408
# [188]	validation-rmse:6.43376
# [189]	validation-rmse:6.43360
# [190]	validation-rmse:6.43347
# [191]	validation-rmse:6.43343
# [192]	validation-rmse:6.43284
# [193]	validation-rmse:6.43259
# [194]	validation-rmse:6.43222
# [195]	validation-rmse:6.43187
# [196]	validation-rmse:6.43157
# [197]	validation-rmse:6.43102
# [198]	validation-rmse:6.43084
# [199]	validation-rmse:6.43085
# [200]	validation-rmse:6.43072
# [201]	validation-rmse:6.43048
# [202]	validation-rmse:6.43004
# [203]	validation-rmse:6.42961
# [204]	validation-rmse:6.42896
# [205]	validation-rmse:6.42861
# [206]	validation-rmse:6.42831
# [207]	validation-rmse:6.42808
# [208]	validation-rmse:6.42801
# [209]	validation-rmse:6.42755
# [210]	validation-rmse:6.42700
# [211]	validation-rmse:6.42653
# [212]	validation-rmse:6.42617
# [213]	validation-rmse:6.42564
# [214]	validation-rmse:6.42532
# [215]	validation-rmse:6.42478
# [216]	validation-rmse:6.42448
# [217]	validation-rmse:6.42402
# [218]	validation-rmse:6.42359
# [219]	validation-rmse:6.42338
# [220]	validation-rmse:6.42298
# [221]	validation-rmse:6.42271
# [222]	validation-rmse:6.42247
# [223]	validation-rmse:6.42197
# [224]	validation-rmse:6.42171
# [225]	validation-rmse:6.42122
# [226]	validation-rmse:6.42061
# [227]	validation-rmse:6.42051
# [228]	validation-rmse:6.42004
# [229]	validation-rmse:6.41970
# [230]	validation-rmse:6.41931
# [231]	validation-rmse:6.41891
# [232]	validation-rmse:6.41880
# [233]	validation-rmse:6.41871
# [234]	validation-rmse:6.41846
# [235]	validation-rmse:6.41782
# [236]	validation-rmse:6.41750
# [237]	validation-rmse:6.41718
# [238]	validation-rmse:6.41680
# [239]	validation-rmse:6.41642
# [240]	validation-rmse:6.41611
# [241]	validation-rmse:6.41599
# [242]	validation-rmse:6.41567
# [243]	validation-rmse:6.41528
# [244]	validation-rmse:6.41504
# [245]	validation-rmse:6.41465
# [246]	validation-rmse:6.41431
# [247]	validation-rmse:6.41400
# [248]	validation-rmse:6.41364
# [249]	validation-rmse:6.41342
# [250]	validation-rmse:6.41328
# [251]	validation-rmse:6.41325
# [252]	validation-rmse:6.41308
# [253]	validation-rmse:6.41279
# [254]	validation-rmse:6.41259
# [255]	validation-rmse:6.41198
# [256]	validation-rmse:6.41179
# [257]	validation-rmse:6.41155
# [258]	validation-rmse:6.41131
# [259]	validation-rmse:6.41075
# [260]	validation-rmse:6.41055
# [261]	validation-rmse:6.41016
# [262]	validation-rmse:6.41002
# [263]	validation-rmse:6.41006
# [264]	validation-rmse:6.40985
# [265]	validation-rmse:6.40970
# [266]	validation-rmse:6.40951
# [267]	validation-rmse:6.40926
# [268]	validation-rmse:6.40903
# [269]	validation-rmse:6.40865
# [270]	validation-rmse:6.40830
# [271]	validation-rmse:6.40805
# [272]	validation-rmse:6.40790
# [273]	validation-rmse:6.40767
# [274]	validation-rmse:6.40749
# [275]	validation-rmse:6.40734
# [276]	validation-rmse:6.40696
# [277]	validation-rmse:6.40666
# [278]	validation-rmse:6.40632
# [279]	validation-rmse:6.40581
# [280]	validation-rmse:6.40552
# [281]	validation-rmse:6.40505
# [282]	validation-rmse:6.40472
# [283]	validation-rmse:6.40449
# [284]	validation-rmse:6.40420
# [285]	validation-rmse:6.40377
# [286]	validation-rmse:6.40347
# [287]	validation-rmse:6.40305
# [288]	validation-rmse:6.40283
# [289]	validation-rmse:6.40268
# [290]	validation-rmse:6.40245
# [291]	validation-rmse:6.40219
# [292]	validation-rmse:6.40207
# [293]	validation-rmse:6.40178
# [294]	validation-rmse:6.40135
# [295]	validation-rmse:6.40101
# [296]	validation-rmse:6.40064
# [297]	validation-rmse:6.40041
# [298]	validation-rmse:6.40004
# [299]	validation-rmse:6.39995
# [300]	validation-rmse:6.39958
# [301]	validation-rmse:6.39939
# [302]	validation-rmse:6.39900
# [303]	validation-rmse:6.39883
# [304]	validation-rmse:6.39869
# [305]	validation-rmse:6.39846
# [306]	validation-rmse:6.39837
# [307]	validation-rmse:6.39819
# [308]	validation-rmse:6.39793
# [309]	validation-rmse:6.39771
# [310]	validation-rmse:6.39720
# [311]	validation-rmse:6.39687
# [312]	validation-rmse:6.39660
# [313]	validation-rmse:6.39603
# [314]	validation-rmse:6.39590
# [315]	validation-rmse:6.39579
# [316]	validation-rmse:6.39557
# [317]	validation-rmse:6.39519
# [318]	validation-rmse:6.39501
# [319]	validation-rmse:6.39472
# [320]	validation-rmse:6.39456
# [321]	validation-rmse:6.39437
# [322]	validation-rmse:6.39419
# [323]	validation-rmse:6.39385
# [324]	validation-rmse:6.39350
# [325]	validation-rmse:6.39331
# [326]	validation-rmse:6.39326
# [327]	validation-rmse:6.39311
# [328]	validation-rmse:6.39315
# [329]	validation-rmse:6.39302
# [330]	validation-rmse:6.39281
# [331]	validation-rmse:6.39274
# [332]	validation-rmse:6.39254
# [333]	validation-rmse:6.39242
# [334]	validation-rmse:6.39193
# [335]	validation-rmse:6.39169
# [336]	validation-rmse:6.39148
# [337]	validation-rmse:6.39136
# [338]	validation-rmse:6.39108
# [339]	validation-rmse:6.39103
# [340]	validation-rmse:6.39079
# [341]	validation-rmse:6.39058
# [342]	validation-rmse:6.39045
# [343]	validation-rmse:6.39022
# [344]	validation-rmse:6.39024
# [345]	validation-rmse:6.39007
# [346]	validation-rmse:6.39002
# [347]	validation-rmse:6.38999
# [348]	validation-rmse:6.38977
# [349]	validation-rmse:6.38951
# [350]	validation-rmse:6.38951
# [351]	validation-rmse:6.38944
# [352]	validation-rmse:6.38923
# [353]	validation-rmse:6.38903
# [354]	validation-rmse:6.38885
# [355]	validation-rmse:6.38867
# [356]	validation-rmse:6.38856
# [357]	validation-rmse:6.38845
# [358]	validation-rmse:6.38818
# [359]	validation-rmse:6.38787
# [360]	validation-rmse:6.38751
# [361]	validation-rmse:6.38704
# [362]	validation-rmse:6.38673
# [363]	validation-rmse:6.38648
# [364]	validation-rmse:6.38626
# [365]	validation-rmse:6.38610
# [366]	validation-rmse:6.38573
# [367]	validation-rmse:6.38525
# [368]	validation-rmse:6.38505
# [369]	validation-rmse:6.38483
# [370]	validation-rmse:6.38457
# [371]	validation-rmse:6.38450
# [372]	validation-rmse:6.38420
# [373]	validation-rmse:6.38398
# [374]	validation-rmse:6.38392
# [375]	validation-rmse:6.38368
# [376]	validation-rmse:6.38342
# [377]	validation-rmse:6.38321
# [378]	validation-rmse:6.38318
# [379]	validation-rmse:6.38285
# [380]	validation-rmse:6.38258
# [381]	validation-rmse:6.38225
# [382]	validation-rmse:6.38211
# [383]	validation-rmse:6.38171
# [384]	validation-rmse:6.38155
# [385]	validation-rmse:6.38138
# [386]	validation-rmse:6.38110
# [387]	validation-rmse:6.38089
# [388]	validation-rmse:6.38071
# [389]	validation-rmse:6.38059
# [390]	validation-rmse:6.38023
# [391]	validation-rmse:6.38004
# [392]	validation-rmse:6.37982
# [393]	validation-rmse:6.37962
# [394]	validation-rmse:6.37968
# [395]	validation-rmse:6.37956
# [396]	validation-rmse:6.37937
# [397]	validation-rmse:6.37885
# [398]	validation-rmse:6.37864
# [399]	validation-rmse:6.37815
# [400]	validation-rmse:6.37803
# [401]	validation-rmse:6.37778
# [402]	validation-rmse:6.37749
# [403]	validation-rmse:6.37731
# [404]	validation-rmse:6.37712
# [405]	validation-rmse:6.37698
# [406]	validation-rmse:6.37677
# [407]	validation-rmse:6.37658
# [408]	validation-rmse:6.37647
# [409]	validation-rmse:6.37631
# [410]	validation-rmse:6.37617
# [411]	validation-rmse:6.37575
# [412]	validation-rmse:6.37566
# [413]	validation-rmse:6.37556
# [414]	validation-rmse:6.37533
# [415]	validation-rmse:6.37538
# [416]	validation-rmse:6.37541
# [417]	validation-rmse:6.37530
# [418]	validation-rmse:6.37511
# [419]	validation-rmse:6.37512
# [420]	validation-rmse:6.37496
# [421]	validation-rmse:6.37483
# [422]	validation-rmse:6.37478
# [423]	validation-rmse:6.37466
# [424]	validation-rmse:6.37440
# [425]	validation-rmse:6.37416
# [426]	validation-rmse:6.37387
# [427]	validation-rmse:6.37384
# [428]	validation-rmse:6.37367
# [429]	validation-rmse:6.37357
# [430]	validation-rmse:6.37345
# [431]	validation-rmse:6.37330
# [432]	validation-rmse:6.37293
# [433]	validation-rmse:6.37265
# [434]	validation-rmse:6.37245
# [435]	validation-rmse:6.37236
# [436]	validation-rmse:6.37233
# [437]	validation-rmse:6.37222
# [438]	validation-rmse:6.37221
# [439]	validation-rmse:6.37218
# [440]	validation-rmse:6.37198
# [441]	validation-rmse:6.37195
# [442]	validation-rmse:6.37190
# [443]	validation-rmse:6.37189
# [444]	validation-rmse:6.37171
# [445]	validation-rmse:6.37159
# [446]	validation-rmse:6.37148
# [447]	validation-rmse:6.37152
# [448]	validation-rmse:6.37128
# [449]	validation-rmse:6.37125
# [450]	validation-rmse:6.37110
# [451]	validation-rmse:6.37086
# [452]	validation-rmse:6.37067
# [453]	validation-rmse:6.37035
# [454]	validation-rmse:6.37019
# [455]	validation-rmse:6.36995
# [456]	validation-rmse:6.36964
# [457]	validation-rmse:6.36935
# [458]	validation-rmse:6.36895
# [459]	validation-rmse:6.36883
# [460]	validation-rmse:6.36862
# [461]	validation-rmse:6.36842
# [462]	validation-rmse:6.36826
# [463]	validation-rmse:6.36789
# [464]	validation-rmse:6.36769
# [465]	validation-rmse:6.36769
# [466]	validation-rmse:6.36764
# [467]	validation-rmse:6.36735
# [468]	validation-rmse:6.36717
# [469]	validation-rmse:6.36706
# [470]	validation-rmse:6.36690
# [471]	validation-rmse:6.36676
# [472]	validation-rmse:6.36671
# [473]	validation-rmse:6.36656
# [474]	validation-rmse:6.36627
# [475]	validation-rmse:6.36626
# [476]	validation-rmse:6.36614
# [477]	validation-rmse:6.36595
# [478]	validation-rmse:6.36597
# [479]	validation-rmse:6.36584
# [480]	validation-rmse:6.36566
# [481]	validation-rmse:6.36531
# [482]	validation-rmse:6.36523
# [483]	validation-rmse:6.36517
# [484]	validation-rmse:6.36487
# [485]	validation-rmse:6.36472
# [486]	validation-rmse:6.36459
# [487]	validation-rmse:6.36439
# [488]	validation-rmse:6.36424
# [489]	validation-rmse:6.36401
# [490]	validation-rmse:6.36386
# [491]	validation-rmse:6.36369
# [492]	validation-rmse:6.36348
# [493]	validation-rmse:6.36316
# [494]	validation-rmse:6.36311
# [495]	validation-rmse:6.36313
# [496]	validation-rmse:6.36295
# [497]	validation-rmse:6.36292
# [498]	validation-rmse:6.36283
# [499]	validation-rmse:6.36268
# [500]	validation-rmse:6.36237
# [501]	validation-rmse:6.36220
# [502]	validation-rmse:6.36207
# [503]	validation-rmse:6.36177
# [504]	validation-rmse:6.36172
# [505]	validation-rmse:6.36153
# [506]	validation-rmse:6.36143
# [507]	validation-rmse:6.36129
# [508]	validation-rmse:6.36116
# [509]	validation-rmse:6.36092
# [510]	validation-rmse:6.36073
# [511]	validation-rmse:6.36044
# [512]	validation-rmse:6.36036
# [513]	validation-rmse:6.36024
# [514]	validation-rmse:6.36008
# [515]	validation-rmse:6.36008
# [516]	validation-rmse:6.35995
# [517]	validation-rmse:6.36001
# [518]	validation-rmse:6.35985
# [519]	validation-rmse:6.35968
# [520]	validation-rmse:6.35961
# [521]	validation-rmse:6.35962
# [522]	validation-rmse:6.35963
# [523]	validation-rmse:6.35945
# [524]	validation-rmse:6.35932
# [525]	validation-rmse:6.35923
# [526]	validation-rmse:6.35909
# [527]	validation-rmse:6.35908
# [528]	validation-rmse:6.35911
# [529]	validation-rmse:6.35892
# [530]	validation-rmse:6.35873
# [531]	validation-rmse:6.35860
# [532]	validation-rmse:6.35828
# [533]	validation-rmse:6.35824
# [534]	validation-rmse:6.35805
# [535]	validation-rmse:6.35791
# [536]	validation-rmse:6.35774
# [537]	validation-rmse:6.35752
# [538]	validation-rmse:6.35727
# [539]	validation-rmse:6.35711
# [540]	validation-rmse:6.35700
# [541]	validation-rmse:6.35692
# [542]	validation-rmse:6.35679
# [543]	validation-rmse:6.35677
# [544]	validation-rmse:6.35678
# [545]	validation-rmse:6.35676
# [546]	validation-rmse:6.35671
# [547]	validation-rmse:6.35666
# [548]	validation-rmse:6.35675
# [549]	validation-rmse:6.35666
# [550]	validation-rmse:6.35656
# [551]	validation-rmse:6.35636
# [552]	validation-rmse:6.35630
# [553]	validation-rmse:6.35613
# [554]	validation-rmse:6.35621
# [555]	validation-rmse:6.35604
# [556]	validation-rmse:6.35586
# [557]	validation-rmse:6.35563
# [558]	validation-rmse:6.35564
# [559]	validation-rmse:6.35548
# [560]	validation-rmse:6.35528
# [561]	validation-rmse:6.35488
# [562]	validation-rmse:6.35475
# [563]	validation-rmse:6.35457
# [564]	validation-rmse:6.35443
# [565]	validation-rmse:6.35436
# [566]	validation-rmse:6.35431
# [567]	validation-rmse:6.35407
# [568]	validation-rmse:6.35379
# [569]	validation-rmse:6.35378
# [570]	validation-rmse:6.35371
# [571]	validation-rmse:6.35347
# [572]	validation-rmse:6.35313
# [573]	validation-rmse:6.35301
# [574]	validation-rmse:6.35292
# [575]	validation-rmse:6.35259
# [576]	validation-rmse:6.35244
# [577]	validation-rmse:6.35232
# [578]	validation-rmse:6.35216
# [579]	validation-rmse:6.35197
# [580]	validation-rmse:6.35184
# [581]	validation-rmse:6.35171
# [582]	validation-rmse:6.35158
# [583]	validation-rmse:6.35155
# [584]	validation-rmse:6.35141
# [585]	validation-rmse:6.35150
# [586]	validation-rmse:6.35138
# [587]	validation-rmse:6.35135
# [588]	validation-rmse:6.35117
# [589]	validation-rmse:6.35092
# [590]	validation-rmse:6.35080
# [591]	validation-rmse:6.35072
# [592]	validation-rmse:6.35060
# [593]	validation-rmse:6.35054
# [594]	validation-rmse:6.35044
# [595]	validation-rmse:6.35023
# [596]	validation-rmse:6.35024
# [597]	validation-rmse:6.35010
# [598]	validation-rmse:6.34977
# [599]	validation-rmse:6.34970
# [600]	validation-rmse:6.34944
# [601]	validation-rmse:6.34945
# [602]	validation-rmse:6.34938
# [603]	validation-rmse:6.34915
# [604]	validation-rmse:6.34891
# [605]	validation-rmse:6.34870
# [606]	validation-rmse:6.34850
# [607]	validation-rmse:6.34852
# [608]	validation-rmse:6.34834
# [609]	validation-rmse:6.34821
# [610]	validation-rmse:6.34807
# [611]	validation-rmse:6.34796
# [612]	validation-rmse:6.34790
# [613]	validation-rmse:6.34777
# [614]	validation-rmse:6.34769
# [615]	validation-rmse:6.34750
# [616]	validation-rmse:6.34707
# [617]	validation-rmse:6.34703
# [618]	validation-rmse:6.34698
# [619]	validation-rmse:6.34688
# [620]	validation-rmse:6.34668
# [621]	validation-rmse:6.34654
# [622]	validation-rmse:6.34654
# [623]	validation-rmse:6.34648
# [624]	validation-rmse:6.34656
# [625]	validation-rmse:6.34648
# [626]	validation-rmse:6.34634
# [627]	validation-rmse:6.34633
# [628]	validation-rmse:6.34629
# [629]	validation-rmse:6.34613
# [630]	validation-rmse:6.34611
# [631]	validation-rmse:6.34605
# [632]	validation-rmse:6.34591
# [633]	validation-rmse:6.34579
# [634]	validation-rmse:6.34573
# [635]	validation-rmse:6.34559
# [636]	validation-rmse:6.34558
# [637]	validation-rmse:6.34557
# [638]	validation-rmse:6.34547
# [639]	validation-rmse:6.34545
# [640]	validation-rmse:6.34505
# [641]	validation-rmse:6.34506
# [642]	validation-rmse:6.34503
# [643]	validation-rmse:6.34500
# [644]	validation-rmse:6.34477
# [645]	validation-rmse:6.34472
# [646]	validation-rmse:6.34472
# [647]	validation-rmse:6.34473
# [648]	validation-rmse:6.34462
# [649]	validation-rmse:6.34442
# [650]	validation-rmse:6.34423
# [651]	validation-rmse:6.34426
# [652]	validation-rmse:6.34401
# [653]	validation-rmse:6.34393
# [654]	validation-rmse:6.34376
# [655]	validation-rmse:6.34378
# [656]	validation-rmse:6.34363
# [657]	validation-rmse:6.34356
# [658]	validation-rmse:6.34328
# [659]	validation-rmse:6.34325
# [660]	validation-rmse:6.34311
# [661]	validation-rmse:6.34303
# [662]	validation-rmse:6.34303
# [663]	validation-rmse:6.34293
# [664]	validation-rmse:6.34310
# [665]	validation-rmse:6.34289
# [666]	validation-rmse:6.34279
# [667]	validation-rmse:6.34269
# [668]	validation-rmse:6.34260
# [669]	validation-rmse:6.34238
# [670]	validation-rmse:6.34223
# [671]	validation-rmse:6.34210
# [672]	validation-rmse:6.34207
# [673]	validation-rmse:6.34201
# [674]	validation-rmse:6.34192
# [675]	validation-rmse:6.34207
# [676]	validation-rmse:6.34191
# [677]	validation-rmse:6.34197
# [678]	validation-rmse:6.34185
# [679]	validation-rmse:6.34168
# [680]	validation-rmse:6.34158
# [681]	validation-rmse:6.34146
# [682]	validation-rmse:6.34140
# [683]	validation-rmse:6.34138
# [684]	validation-rmse:6.34125
# [685]	validation-rmse:6.34119
# [686]	validation-rmse:6.34118
# [687]	validation-rmse:6.34103
# [688]	validation-rmse:6.34101
# [689]	validation-rmse:6.34087
# [690]	validation-rmse:6.34075
# [691]	validation-rmse:6.34056
# [692]	validation-rmse:6.34040
# [693]	validation-rmse:6.34015
# [694]	validation-rmse:6.34005
# [695]	validation-rmse:6.33987
# [696]	validation-rmse:6.33983
# [697]	validation-rmse:6.33979
# [698]	validation-rmse:6.33971
# [699]	validation-rmse:6.33974
# [700]	validation-rmse:6.33952
# [701]	validation-rmse:6.33946
# [702]	validation-rmse:6.33958
# [703]	validation-rmse:6.33951
# [704]	validation-rmse:6.33946
# [705]	validation-rmse:6.33930
# [706]	validation-rmse:6.33904
# [707]	validation-rmse:6.33908
# [708]	validation-rmse:6.33892
# [709]	validation-rmse:6.33888
# [710]	validation-rmse:6.33870
# [711]	validation-rmse:6.33861
# [712]	validation-rmse:6.33847
# [713]	validation-rmse:6.33842
# [714]	validation-rmse:6.33833
# [715]	validation-rmse:6.33822
# [716]	validation-rmse:6.33830
# [717]	validation-rmse:6.33819
# [718]	validation-rmse:6.33814
# [719]	validation-rmse:6.33802
# [720]	validation-rmse:6.33802
# [721]	validation-rmse:6.33787
# [722]	validation-rmse:6.33773
# [723]	validation-rmse:6.33754
# [724]	validation-rmse:6.33732
# [725]	validation-rmse:6.33714
# [726]	validation-rmse:6.33689
# [727]	validation-rmse:6.33675
# [728]	validation-rmse:6.33656
# [729]	validation-rmse:6.33647
# [730]	validation-rmse:6.33638
# [731]	validation-rmse:6.33636
# [732]	validation-rmse:6.33618
# [733]	validation-rmse:6.33607
# [734]	validation-rmse:6.33600
# [735]	validation-rmse:6.33595
# [736]	validation-rmse:6.33595
# [737]	validation-rmse:6.33591
# [738]	validation-rmse:6.33585
# [739]	validation-rmse:6.33559
# [740]	validation-rmse:6.33557
# [741]	validation-rmse:6.33540
# [742]	validation-rmse:6.33534
# [743]	validation-rmse:6.33540
# [744]	validation-rmse:6.33526
# [745]	validation-rmse:6.33518
# [746]	validation-rmse:6.33513
# [747]	validation-rmse:6.33514
# [748]	validation-rmse:6.33508
# [749]	validation-rmse:6.33499
# [750]	validation-rmse:6.33497
# [751]	validation-rmse:6.33474
# [752]	validation-rmse:6.33480
# [753]	validation-rmse:6.33486
# [754]	validation-rmse:6.33465
# [755]	validation-rmse:6.33461
# [756]	validation-rmse:6.33457
# [757]	validation-rmse:6.33448
# [758]	validation-rmse:6.33445
# [759]	validation-rmse:6.33440
# [760]	validation-rmse:6.33427
# [761]	validation-rmse:6.33406
# [762]	validation-rmse:6.33400
# [763]	validation-rmse:6.33401
# [764]	validation-rmse:6.33395
# [765]	validation-rmse:6.33388
# [766]	validation-rmse:6.33372
# [767]	validation-rmse:6.33379
# [768]	validation-rmse:6.33383
# [769]	validation-rmse:6.33372
# [770]	validation-rmse:6.33365
# [771]	validation-rmse:6.33366
# [772]	validation-rmse:6.33365
# [773]	validation-rmse:6.33364
# [774]	validation-rmse:6.33363
# [775]	validation-rmse:6.33350
# [776]	validation-rmse:6.33317
# [777]	validation-rmse:6.33316
# [778]	validation-rmse:6.33307
# [779]	validation-rmse:6.33306
# [780]	validation-rmse:6.33279
# [781]	validation-rmse:6.33267
# [782]	validation-rmse:6.33249
# [783]	validation-rmse:6.33235
# [784]	validation-rmse:6.33204
# [785]	validation-rmse:6.33197
# [786]	validation-rmse:6.33194
# [787]	validation-rmse:6.33177
# [788]	validation-rmse:6.33186
# [789]	validation-rmse:6.33172
# [790]	validation-rmse:6.33167
# [791]	validation-rmse:6.33159
# [792]	validation-rmse:6.33160
# [793]	validation-rmse:6.33168
# [794]	validation-rmse:6.33172
# [795]	validation-rmse:6.33154
# [796]	validation-rmse:6.33146
# [797]	validation-rmse:6.33128
# [798]	validation-rmse:6.33118
# [799]	validation-rmse:6.33111
# [800]	validation-rmse:6.33117
# [801]	validation-rmse:6.33116
# [802]	validation-rmse:6.33095
# [803]	validation-rmse:6.33097
# [804]	validation-rmse:6.33101
# [805]	validation-rmse:6.33097
# [806]	validation-rmse:6.33088
# [807]	validation-rmse:6.33089
# [808]	validation-rmse:6.33091
# [809]	validation-rmse:6.33092
# [810]	validation-rmse:6.33079
# [811]	validation-rmse:6.33072
# [812]	validation-rmse:6.33076
# [813]	validation-rmse:6.33066
# [814]	validation-rmse:6.33062
# [815]	validation-rmse:6.33050
# [816]	validation-rmse:6.33026
# [817]	validation-rmse:6.33024
# [818]	validation-rmse:6.33027
# [819]	validation-rmse:6.33023
# [820]	validation-rmse:6.33019
# [821]	validation-rmse:6.33007
# [822]	validation-rmse:6.32995
# [823]	validation-rmse:6.32997
# [824]	validation-rmse:6.32989
# [825]	validation-rmse:6.32990
# [826]	validation-rmse:6.32972
# [827]	validation-rmse:6.32970
# [828]	validation-rmse:6.32958
# [829]	validation-rmse:6.32960
# [830]	validation-rmse:6.32935
# [831]	validation-rmse:6.32935
# [832]	validation-rmse:6.32924
# [833]	validation-rmse:6.32914
# [834]	validation-rmse:6.32909
# [835]	validation-rmse:6.32881
# [836]	validation-rmse:6.32883
# [837]	validation-rmse:6.32881
# [838]	validation-rmse:6.32873
# [839]	validation-rmse:6.32861
# [840]	validation-rmse:6.32864
# [841]	validation-rmse:6.32855
# [842]	validation-rmse:6.32851
# [843]	validation-rmse:6.32846
# [844]	validation-rmse:6.32829
# [845]	validation-rmse:6.32817
# [846]	validation-rmse:6.32795
# [847]	validation-rmse:6.32786
# [848]	validation-rmse:6.32772
# [849]	validation-rmse:6.32758
# [850]	validation-rmse:6.32751
# [851]	validation-rmse:6.32749
# [852]	validation-rmse:6.32739
# [853]	validation-rmse:6.32729
# [854]	validation-rmse:6.32725
# [855]	validation-rmse:6.32729
# [856]	validation-rmse:6.32718
# [857]	validation-rmse:6.32688
# [858]	validation-rmse:6.32680
# [859]	validation-rmse:6.32676
# [860]	validation-rmse:6.32663
# [861]	validation-rmse:6.32637
# [862]	validation-rmse:6.32633
# [863]	validation-rmse:6.32626
# [864]	validation-rmse:6.32634
# [865]	validation-rmse:6.32645
# [866]	validation-rmse:6.32627
# [867]	validation-rmse:6.32618
# [868]	validation-rmse:6.32603
# [869]	validation-rmse:6.32574
# [870]	validation-rmse:6.32571
# [871]	validation-rmse:6.32574
# [872]	validation-rmse:6.32589
# [873]	validation-rmse:6.32584
# [874]	validation-rmse:6.32579
# [875]	validation-rmse:6.32573
# [876]	validation-rmse:6.32547
# [877]	validation-rmse:6.32546
# [878]	validation-rmse:6.32552
# [879]	validation-rmse:6.32545
# [880]	validation-rmse:6.32552
# [881]	validation-rmse:6.32532
# [882]	validation-rmse:6.32527
# [883]	validation-rmse:6.32525
# [884]	validation-rmse:6.32520
# [885]	validation-rmse:6.32506
# [886]	validation-rmse:6.32466
# [887]	validation-rmse:6.32466
# [888]	validation-rmse:6.32470
# [889]	validation-rmse:6.32461
# [890]	validation-rmse:6.32450
# [891]	validation-rmse:6.32444
# [892]	validation-rmse:6.32432
# [893]	validation-rmse:6.32420
# [894]	validation-rmse:6.32408
# [895]	validation-rmse:6.32403
# [896]	validation-rmse:6.32392
# [897]	validation-rmse:6.32379
# [898]	validation-rmse:6.32383
# [899]	validation-rmse:6.32379
# [900]	validation-rmse:6.32371
# [901]	validation-rmse:6.32332
# [902]	validation-rmse:6.32334
# [903]	validation-rmse:6.32343
# [904]	validation-rmse:6.32333
# [905]	validation-rmse:6.32333
# [906]	validation-rmse:6.32335
# [907]	validation-rmse:6.32332
# [908]	validation-rmse:6.32329
# [909]	validation-rmse:6.32330
# [910]	validation-rmse:6.32319
# [911]	validation-rmse:6.32313
# [912]	validation-rmse:6.32315
# [913]	validation-rmse:6.32306
# [914]	validation-rmse:6.32299
# [915]	validation-rmse:6.32289
# [916]	validation-rmse:6.32287
# [917]	validation-rmse:6.32273
# [918]	validation-rmse:6.32267
# [919]	validation-rmse:6.32259
# [920]	validation-rmse:6.32237
# [921]	validation-rmse:6.32216
# [922]	validation-rmse:6.32213
# [923]	validation-rmse:6.32221
# [924]	validation-rmse:6.32206
# [925]	validation-rmse:6.32204
# [926]	validation-rmse:6.32193
# [927]	validation-rmse:6.32191
# [928]	validation-rmse:6.32170
# [929]	validation-rmse:6.32149
# [930]	validation-rmse:6.32156
# [931]	validation-rmse:6.32149
# [932]	validation-rmse:6.32146
# [933]	validation-rmse:6.32152
# [934]	validation-rmse:6.32135
# [935]	validation-rmse:6.32131
# [936]	validation-rmse:6.32133
# [937]	validation-rmse:6.32130
# [938]	validation-rmse:6.32129
# [939]	validation-rmse:6.32120
# [940]	validation-rmse:6.32104
# [941]	validation-rmse:6.32097
# [942]	validation-rmse:6.32088
# [943]	validation-rmse:6.32082
# [944]	validation-rmse:6.32089
# [945]	validation-rmse:6.32102
# [946]	validation-rmse:6.32074
# [947]	validation-rmse:6.32082
# [948]	validation-rmse:6.32074
# [949]	validation-rmse:6.32066
# [950]	validation-rmse:6.32043
# [951]	validation-rmse:6.32020
# [952]	validation-rmse:6.32007
# [953]	validation-rmse:6.32009
# [954]	validation-rmse:6.32009
# [955]	validation-rmse:6.32004
# [956]	validation-rmse:6.32001
# [957]	validation-rmse:6.31998
# [958]	validation-rmse:6.31987
# [959]	validation-rmse:6.31992
# [960]	validation-rmse:6.31981
# [961]	validation-rmse:6.31981
# [962]	validation-rmse:6.31983
# [963]	validation-rmse:6.31978
# [964]	validation-rmse:6.31960
# [965]	validation-rmse:6.31961
# [966]	validation-rmse:6.31958
# [967]	validation-rmse:6.31948
# [968]	validation-rmse:6.31946
# [969]	validation-rmse:6.31950
# [970]	validation-rmse:6.31951
# [971]	validation-rmse:6.31957
# [972]	validation-rmse:6.31957
# [973]	validation-rmse:6.31959
# [974]	validation-rmse:6.31942
# [975]	validation-rmse:6.31937
# [976]	validation-rmse:6.31937
# [977]	validation-rmse:6.31927
# [978]	validation-rmse:6.31919
# [979]	validation-rmse:6.31919
# [980]	validation-rmse:6.31907
# [981]	validation-rmse:6.31907
# [982]	validation-rmse:6.31898
# [983]	validation-rmse:6.31904
# [984]	validation-rmse:6.31907
# [985]	validation-rmse:6.31894
# [986]	validation-rmse:6.31894
# [987]	validation-rmse:6.31893
# [988]	validation-rmse:6.31877
# [989]	validation-rmse:6.31896
# [990]	validation-rmse:6.31893
# [991]	validation-rmse:6.31875
# [992]	validation-rmse:6.31862
# [993]	validation-rmse:6.31853
# [994]	validation-rmse:6.31855
# [995]	validation-rmse:6.31848
# [996]	validation-rmse:6.31855
# [997]	validation-rmse:6.31850
# [998]	validation-rmse:6.31857
# [999]	validation-rmse:6.31845
# /home/ubuntu/anaconda3/envs/mlops-env/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [08:26:59] WARNING: /workspace/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.
#   warnings.warn(smsg, UserWarning)
# /home/ubuntu/anaconda3/envs/mlops-env/lib/python3.11/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /home/ubuntu/anaconda3/envs/mlops-env/lib/python3.11/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# array([14.782765 ,  7.184751 , 15.971323 , ..., 13.464008 ,  6.7352147,
#         8.184539 ], dtype=float32)

# %%
mlflow.sklearn.autolog()

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):
    with mlflow.start_run():
        # log detail
        mlflow.set_tag("developer", "christopher")
        # log parameter
        mlflow.log_param("train-data-path", "../data/green_tripdata_2021-01.parquet")
        mlflow.log_param("valid-data-path", "../data/green_tripdata_2021-02.parquet")

        # log artifact for preprocessor
        mlflow.log_artifact("models/preprocessor.b", artifact_path = "preprocessor")

        super_model = model_class()
        super_model.fit(x_train, y_train)

        y_pred = super_model.predict(x_val)
        rmse = root_mean_squared_error(y_val, y_pred)

        # log metric
        mlflow.log_metric("rmse", rmse)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 15
#      12 mlflow.log_artifact("models/preprocessor.b", artifact_path = "preprocessor")
#      14 super_model = model_class()
# ---> 15 super_model.fit(x_train, y_train)
#      17 y_pred = super_model.predict(x_val)
#      18 rmse = root_mean_squared_error(y_val, y_pred)
#
# File ~/anaconda3/envs/mlops-env/lib/python3.11/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/envs/mlops-env/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:489, in BaseForest.fit(self, X, y, sample_weight)
#     478 trees = [
#     479     self._make_estimator(append=False, random_state=random_state)
#     480     for i in range(n_more_estimators)
#     481 ]
#     483 # Parallel loop: we prefer the threading backend as the Cython code
#     484 # for fitting the trees is internally releasing the Python GIL
#     485 # making threading more efficient than multiprocessing in
#     486 # that case. However, for joblib 0.12+ we respect any
#     487 # parallel_backend contexts set at a higher level,
#     488 # since correctness does not rely on using threads.
# --> 489 trees = Parallel(
#     490     n_jobs=self.n_jobs,
#     491     verbose=self.verbose,
#     492     prefer="threads",
#     493 )(
#     494     delayed(_parallel_build_trees)(
#     495         t,
#     496         self.bootstrap,
#     497         X,
#     498         y,
#     499         sample_weight,
#     500         i,
#     501         len(trees),
#     502         verbose=self.verbose,
#     503         class_weight=self.class_weight,
#     504         n_samples_bootstrap=n_samples_bootstrap,
#     505         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     506     )
#     507     for i, t in enumerate(trees)
#     508 )
#     510 # Collect newly grown trees
#     511 self.estimators_.extend(trees)
#
# File ~/anaconda3/envs/mlops-env/lib/python3.11/site-packages/sklearn/utils/parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File ~/anaconda3/envs/mlops-env/lib/python3.11/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~/anaconda3/envs/mlops-env/lib/python3.11/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~/anaconda3/envs/mlops-env/lib/python3.11/site-packages/sklearn/utils/parallel.py:129, in _FuncWrapper.__call__(self, *args, **kwargs)
#     127     config = {}
#     128 with config_context(**config):
# --> 129     return self.function(*args, **kwargs)
#
# File ~/anaconda3/envs/mlops-env/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:192, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     189     elif class_weight == "balanced_subsample":
#     190         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 192     tree._fit(
#     193         X,
#     194         y,
#     195         sample_weight=curr_sample_weight,
#     196         check_input=False,
#     197         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     198     )
#     199 else:
#     200     tree._fit(
#     201         X,
#     202         y,
#    (...)
#     205         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     206     )
#
# File ~/anaconda3/envs/mlops-env/lib/python3.11/site-packages/sklearn/tree/_classes.py:472, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     461 else:
#     462     builder = BestFirstTreeBuilder(
#     463         splitter,
#     464         min_samples_split,
#    (...)
#     469         self.min_impurity_decrease,
#     470     )
# --> 472 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     474 if self.n_outputs_ == 1 and is_classifier(self):
#     475     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:
